# %% [markdown]
# #Основные понятия
# **Кросс-валидация** - это метод оценки модели машинного обучения, который улучшает надёжность валидационного процесса путём разделения данных на несколько частей, или "фолдов". Модель обучается на некоторых из этих фолдов и валидируется на оставшихся, процесс повторяется несколько раз с разными наборами фолдов. Это позволяет использовать все доступные данные как для обучения, так и для валидации модели, предоставляя более обобщённую оценку её качества.
#
# **L1-регуляризация (лассо регуляризация)** - метод регуляризации, при котором к функции потерь добавляется сумма абсолютных значений коэффициентов модели, умноженная на регуляризационный параметр. L1-регуляризация может привести к обнулению некоторых коэффициентов, что делает её полезной для выбора признаков и создания разреженных моделей.
#
# **L2-регуляризация (ридж-регуляризация)** - эта форма регуляризации добавляет к функции потерь сумму квадратов коэффициентов модели, каждый из которых умножается на регуляризационный параметр. В отличие от L1, L2-регуляризация не обнуляет коэффициенты, а штрафует большие значения, способствуя более сглаженной и стабильной модели.
#
# **Переобучение (Overfitting)** - это явление в машинном обучении, когда модель слишком тесно адаптируется к обучающему набору данных, включая шум и аномалии. В результате такая модель показывает высокую точность на обучающей выборке, но плохо справляется с предсказаниями на новых, невиданных данных, поскольку она уловила в данных некоторые случайные закономерности, не имеющие отношения к реальной задаче.
#
# **Недообучение (Underfitting)** - противоположное явление переобучению, происходит, когда модель не может адекватно уловить зависимости в данных, даже на обучающем наборе, что приводит к низкой производительности как на обучающем, так и на валидационном или тестовом наборе данных. Это может быть результатом слишком простой модели, недостатка данных или недостаточной обучения модели.
#
# **Способность к обобщению (Generalization Ability)** - способность модели машинного обучения работать адекватно на новых, ранее невиданных данных. Следовательно, цель обучения модели состоит в том, чтобы не только хорошо работать на данных, на которых она была обучена, но и сохранять высокую точность на данных вне обучающей выборке. Оценка способности модели к обобщению обычно производится на валидационном наборе данных или через методы кросс-валидации.

# %% [markdown]
# ##Задание 1
#
# **Анализ Переобучения и Недообучения**
#
# - Создайте две модели: модель линейной регрессии и модель полиномиальной регрессии высокой степени, используя один и тот же набор данных. Обучите эти модели, затем оцените их производительность на тренировочном и тестовом наборах данных.
# - Какая модель показывает признаки переобучения, а какая - признаки недообучения?
# - Какие выводы можно сделать о влиянии сложности модели на её способность к обобщению

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score

# %%
from sklearn.datasets import load_iris

# Загружаем набор данных Iris
iris = load_iris()

# Преобразуем данные в DataFrame
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Добавляем целевую переменную
iris_df['target'] = iris.target

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
iris_df.describe().round(2)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count             150.00            150.00             150.00
# mean                5.84              3.06               3.76
# std                 0.83              0.44               1.77
# min                 4.30              2.00               1.00
# 25%                 5.10              2.80               1.60
# 50%                 5.80              3.00               4.35
# 75%                 6.40              3.30               5.10
# max                 7.90              4.40               6.90
#
#        petal width (cm)  target
# count            150.00  150.00
# mean               1.20    1.00
# std                0.76    0.82
# min                0.10    0.00
# 25%                0.30    0.00
# 50%                1.30    1.00
# 75%                1.80    2.00
# max                2.50    2.00

# %%
iris_df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
# Визуализация гистограмм
plt.figure(figsize=(15, 10))
for i, column in enumerate(iris_df.columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(iris_df[column], kde=True)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data= iris_df, ax=ax)
plt.show()

# %%
iris_df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
X = iris_df.drop('target', axis=1)
Y = iris_df['target']
X_scaled = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, train_size=0.8, random_state = 42)

# %%
X_train.shape, y_train.shape
# Out:
# ((120, 4), (120,))

# %%
X = iris_df.drop('target', axis=1)
Y = iris_df['target']
X_scaled = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, train_size=0.8, random_state = 42)


# Создание и обучение модели логистической регрессии
lg = LogisticRegression(class_weight='balanced', max_iter=200)
lg.fit(X_scaled, Y)


# После обучения модели можно получить коэффициенты\
lg.coef_
# Out:
# array([[-1.07659238,  1.15977648, -1.92814138, -1.81227307],
#        [ 0.5899243 , -0.36263595, -0.36461312, -0.82700241],
#        [ 0.48666809, -0.79714052,  2.2927545 ,  2.63927548]])

# %%
feature_names = X.columns
coefficients = lg.coef_  # lg.coef_ возвращает массив в массиве, если модель обучена на двухмерном X

# Связывание имен признаков с их коэффициентами
feature_importances = zip(feature_names, coefficients)

# Преобразование в список для более удобного отображения
feature_importance_list = list(feature_importances)

# Отображение признаков и их коэффициентов
for feature, coef in feature_importance_list:
    print(f"{feature}: {coef}")
# Out:
# sepal length (cm): [-1.07659238  1.15977648 -1.92814138 -1.81227307]
# sepal width (cm): [ 0.5899243  -0.36263595 -0.36461312 -0.82700241]
# petal length (cm): [ 0.48666809 -0.79714052  2.2927545   2.63927548]

# %% [markdown]
# 1. **Коэффициенты для каждого класса**:  модель логистической регрессии обучается на три класса (в данном случае три вида ирисов). Каждый класс имеет свой набор коэффициентов, которые показывают, как каждый признак влияет на вероятность принадлежности к этому классу.
#
# 2. **Значение коэффициентов**:
#    - **Положительные коэффициенты**: Увеличивают вероятность принадлежности к классу. Если признак увеличивается, то вероятность принадлежности к этому классу также увеличивается.
#    - **Отрицательные коэффициенты**: Уменьшают вероятность принадлежности к классу. Если признак увеличивается, то вероятность принадлежности к этому классу уменьшается.

# %%
accuracy_test = accuracy_score(y_test, lg.predict(X_test))
#Y_pred_test_lg = lg.predict(X_test)


accuracy_train = accuracy_score(y_train, lg.predict(X_train))
#Y_pred_train_lg = lg.predict(X_train)

print("Логистическая регрессия:")
print("Тренировочный accuracy:", accuracy_train)
print("Тестовый accuracy:", accuracy_test)
# Out:
# Логистическая регрессия:
# Тренировочный accuracy: 0.9666666666666667
# Тестовый accuracy: 1.0

# %% [markdown]
# Модель склонна к переобучению.

# %% [markdown]
# ##Задание 2
#
# Реализация Кросс-Валидации
#
#  -   Реализуйте процесс 5-кратной кросс-валидации для модели полиномиальной линейной регрессии, используя предоставленный набор данных.
#  -  	Как изменяется средняя точность модели с использованием кросс-валидации по сравнению с однократной оценкой?
#  - 	Объясните, почему кросс-валидация может дать более надежную оценку эффективности модели.
#
# Вопросы к заданию:
# - Каковы преимущества использования кросс-валидации перед оценкой на одном разделении?
# - Как 10-кратная кросс-валидация может влиять на результаты по сравнению с 5-кратной?

# %%
# Однократная оценка на тестовых данных
single_score = accuracy_score(y_test, lg.predict(X_test))
print("Однократная оценка эффективности (accuracy):", single_score)

# 5-кратная кросс-валидация на всем датасете
cross_val_scores = cross_val_score(lg, X, Y, cv=5, scoring='accuracy')
print("Среднее значение accuracy по 5-кратной кросс-валидации:", cross_val_scores.mean())

scores_10 = cross_val_score(lg, X, Y, cv=10, scoring='accuracy')
print("Среднее значение accuracy при 10-кратной кросс-валидации:", scores_10.mean())
# Out:
# Однократная оценка эффективности (accuracy): 1.0
# Среднее значение accuracy по 5-кратной кросс-валидации: 0.9733333333333334
# Среднее значение accuracy при 10-кратной кросс-валидации: 0.9733333333333334

# %% [markdown]
# 1. Переобучение: Однократная оценка accuracy = 1
#   указывает на сильное переобучение модели на тестовых данных. Это означает, что модель идеально подстроилась под тестовые данные, но не обязательно будет хорошо работать на новых данных.
#
# 2. Различия в выборках: Кросс-валидация позволяет оценить модель на различных подвыборках данных, что дает более реалистичное представление о генерализации модели. Каждая итерация в процессе кросс-валидации использует разные наборы тренировочных и проверочных данных, что может выявить переобучение или недообучение модели, не видимое при однократном тестировании.

# %% [markdown]
# Сравнивая среднюю точность модели через кросс-валидацию с однократной оценкой, становится видно, что результат однократной оценки значительно выше (accuracy = 1.0), что может свидетельствовать о переобучении модели на конкретном наборе данных. Когда модель тестируется только на одном разделении данных, оценка может не отражать реальную способность модели к обобщению на новые данные.
# Кросс-валидация дает более надежную оценку эффективности модели, потому что она включает многократное тестирование модели на разных подвыборках данных. Это минимизирует влияние случайных подмножеств данных на результаты и позволяет лучше оценить, насколько хорошо модель сможет работать на невиданной ранее информации. По сути, это имитирует процесс "нового встречания" модели с данными и подчеркивает её устойчивость к изменениям в данных.

# %% [markdown]
# ##Задание 3

# %% [markdown]
#  Эксперименты с Регуляризацией
#
# - Добавьте L1 и L2 регуляризацию к вашей модели линейной регрессии. Экспериментируйте с различными значениями параметра регуляризации и оцените влияние каждого типа регуляризации на качество модели на тестовой выборке.
# - Как регуляризация влияет на коэффициенты модели?
# Объясните, почему L1-регуляризация может быть использована для отбора признаков.
#
# Вопросы к заданию:
# - Как определить оптимальное значение параметра регуляризации?
# - Почему L2-регуляризация не приводит к отбору признаков так же, как L1?

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_regression


# Параметры регуляризации для тестирования
alphas = [0.01, 0.1, 1.0, 10.0, 100.0]



for alpha in alphas:
    # Логистическая регрессия с L1 регуляризацией
    logistic_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1/alpha)  # 'liblinear' поддерживает L1
    logistic_l1.fit(X_train, y_train)
    y_pred_l1 = logistic_l1.predict(X_test)
    print(f'L1 Regularization Accuracy с alpha={alpha}: {accuracy_score(y_test, y_pred_l1)}')

for alpha in alphas:
    # Логистическая регрессия с L2 регуляризацией
    logistic_l2 = LogisticRegression(penalty='l2', C=1/alpha)  # По умолчанию 'l2'
    logistic_l2.fit(X_train, y_train)
    y_pred_l2 = logistic_l2.predict(X_test)
    print(f'L2 Regularization Accuracy с alpha={alpha}: {accuracy_score(y_test, y_pred_l2)}')
# Out:
# L1 Regularization Accuracy с alpha=0.01: 1.0
# L1 Regularization Accuracy с alpha=0.1: 1.0
# L1 Regularization Accuracy с alpha=1.0: 0.9666666666666667
# L1 Regularization Accuracy с alpha=10.0: 0.9333333333333333
# L1 Regularization Accuracy с alpha=100.0: 0.3333333333333333
# L2 Regularization Accuracy с alpha=0.01: 1.0
# L2 Regularization Accuracy с alpha=0.1: 1.0
# L2 Regularization Accuracy с alpha=1.0: 1.0
# L2 Regularization Accuracy с alpha=10.0: 0.9666666666666667
# L2 Regularization Accuracy с alpha=100.0: 0.9333333333333333

# %% [markdown]
# Анализ результатов показывает, что модель L1 с параметром alpha 1 дает наилучший результат с accuracy
#  около 0.97, что указывает на достаточно хорошую адекватность модели к данным. С увеличением альфа значение accuracy немного уменьшается
#
# Для модели L2 значение accuracy  достигает наилучшего результата 0.97 при alpha 10.

# %%
import matplotlib.pyplot as plt

# Переопределим данные для создания графиков
accuracy_score_l1 = []
accuracy_score_l2 = []

# Тестируем Lasso регрессию и Ridge регрессию, сохраняем результаты R^2
for alpha in alphas:
    # Логистическая регрессия с L1 регуляризацией
    logistic_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1/alpha)  # 'liblinear' поддерживает L1
    logistic_l1.fit(X_train, y_train)
    y_pred_l1 = logistic_l1.predict(X_test)
    accuracy_score_l1.append(accuracy_score(y_test, y_pred_l1))

for alpha in alphas:
    # Логистическая регрессия с L2 регуляризацией
    logistic_l2 = LogisticRegression(penalty='l2', C=1/alpha)  # По умолчанию 'l2'
    logistic_l2.fit(X_train, y_train)
    y_pred_l2 = logistic_l2.predict(X_test)

    accuracy_score_l2.append(accuracy_score(y_test, y_pred_l2))

# Создаем графики
plt.figure(figsize=(10, 5))
plt.plot(alphas, accuracy_score_l1, label='L1')
plt.plot(alphas, accuracy_score_l2, label='L2')
plt.xscale('log')
plt.xlabel('Alpha (Log Scale)')
plt.ylabel('Accuracy_score')
plt.title('Effect of Regularization on Accuracy_Score')
plt.legend()
plt.show()

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Анализ способности к обобщению
#
# - Постройте графики кривых обучения для вашей модели линейной регрессии, отображая ошибки на тренировочной и валидационной выборке в зависимости от размера обучающей выборки.
# - Что можно сказать о способности модели к обобщению, основываясь на этих графиках?
# Какие шаги можно предпринять, если график указывает на переобучение или недообучение модели?
#
# Вопросы к заданию:
# - Какие факторы могут привести к переобучению модели, согласно графику кривой обучения?
# - Какие методы могут помочь улучшить способность модели к обобщению?

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import learning_curve

# Предполагается, что X и Y уже определены

# Создание модели логистической регрессии
model = LogisticRegression(max_iter=200)

# Получение кривых обучения
train_sizes, train_scores, validation_scores = learning_curve(
    estimator=model,
    X=X,
    y=Y,
    train_sizes=np.linspace(0.1, 1.0, 10),
    cv=5,
    scoring='accuracy'  # Изменено на 'accuracy'
)

# Средние значения и стандартное отклонение ошибок обучения
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Средние значения и стандартное отклонение ошибок валидации
validation_mean = np.mean(validation_scores, axis=1)
validation_std = np.std(validation_scores, axis=1)

# Построение графиков
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color='#DDDDDD')
plt.fill_between(train_sizes, validation_mean - validation_std, validation_mean + validation_std, color='#FFDDDD')
plt.plot(train_sizes, train_mean, 'o-', color='b', label='Training error')
plt.plot(train_sizes, validation_mean, 'o-', color='r', label='Validation error')

plt.title('Learning Curves')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')  # Изменено на 'Accuracy'
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1301, in fit
#     raise ValueError(
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
model2 = LogisticRegression(penalty='l1', solver='liblinear', C=1, max_iter=200)
# Получение кривых обучения
train_sizes, train_scores, validation_scores = learning_curve(
    estimator=model,
    X=X,
    y=Y,
    train_sizes=np.linspace(0.1, 1.0, 10),
    cv=5,
    scoring='accuracy'  # Изменено на 'accuracy'
)

# Средние значения и стандартное отклонение ошибок обучения
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Средние значения и стандартное отклонение ошибок валидации
validation_mean = np.mean(validation_scores, axis=1)
validation_std = np.std(validation_scores, axis=1)

# Построение графиков
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color='#DDDDDD')
plt.fill_between(train_sizes, validation_mean - validation_std, validation_mean + validation_std, color='#FFDDDD')
plt.plot(train_sizes, train_mean, 'o-', color='b', label='Training error')
plt.plot(train_sizes, validation_mean, 'o-', color='r', label='Validation error')

plt.title('Learning Curves')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')  # Изменено на 'Accuracy'
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1301, in fit
#     raise ValueError(
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
model3 = LogisticRegression(penalty='l2', solver='liblinear', C=1/10, max_iter=200)
# Получение кривых обучения
train_sizes, train_scores, validation_scores = learning_curve(
    estimator=model,
    X=X,
    y=Y,
    train_sizes=np.linspace(0.1, 1.0, 10),
    cv=5,
    scoring='accuracy'  # Изменено на 'accuracy'
)

# Средние значения и стандартное отклонение ошибок обучения
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Средние значения и стандартное отклонение ошибок валидации
validation_mean = np.mean(validation_scores, axis=1)
validation_std = np.std(validation_scores, axis=1)

# Построение графиков
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color='#DDDDDD')
plt.fill_between(train_sizes, validation_mean - validation_std, validation_mean + validation_std, color='#FFDDDD')
plt.plot(train_sizes, train_mean, 'o-', color='b', label='Training error')
plt.plot(train_sizes, validation_mean, 'o-', color='r', label='Validation error')

plt.title('Learning Curves')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')  # Изменено на 'Accuracy'
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1301, in fit
#     raise ValueError(
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %% [markdown]
# Основные наблюдения:
# 1. Первоначальное поведение:
#    - При малом размере обучающего набора (около 50-80), ошибка на валидационной выборке  высокая и начинает уменьшаться с увеличением набора данных.
#    - Ошибка на обучающей выборке изначально низкая, что может свидетельствовать о переобучении на малых данных.
#
# 2. Сходимость ошибок:
#    - Начиная с некоторого размера обучающего набора (примерно 110), ошибки на обучающей и валидационной выборках начинают сходиться.
#    - Вполне возможно, что модель стабилизируется, как только достигается определенный объем данных.
#
# 3. Высокая дисперсия валидационной ошибки:
#    - C увеличением  размера обучающей выборки  наблюдается высокая дисперсия валидационной ошибки, о чем свидетельствует широкая полоска вокруг красной линии. высокая дисперсия валидационной ошибки указывает на проблемы с обобщающей способностью модели
# 1. Недостаток данных:
#    - На начальных этапах обучение на малых данных приводит к высокой ошибке на валидации и низкой ошибке на обучении, что свидетельствует о переобучении.
#
# 2. Объем данных имеет значение:
#    - Модель начинает улучшаться по мере увеличения размера обучающего набора, что приводит к уменьшению разницы между ошибкой на обучении и валидацией.
#    - Достигнув определенного объема (примерно 110 и более), ошибки становятся стабильными и равными, наблюдается высокая дисперсия валидационной ошибки,.

# %% [markdown]
# Шаги при переобучении или недообучении:
# - Переобучение: Добавить больше данных, использовать регуляризацию (L1, L2), уменьшить число признаков.
# - Недообучение: Увеличить число признаков (если возможно), уменьшить степень регуляризации, использовать более сложные модели.
#
# Факторы, приводящие к переобучению:
# - Маленький объем тренировочных данных.
# - Слишком сложная модель для данного объема данных.
# - Неиспользование регуляризации.
#
# Методы улучшения обобщения:
# - Кросс-валидация.
# - Регуляризация (L1, L2).
# - Увеличение размера тренировочного набора данных.

# %% [markdown]
# ##Домашнее задание

# %% [markdown]
# Задание
# Ваша задача - построить модель машинного обучения для предсказания целевой переменной на примере датасета ирисы Фишера. В процессе выполнения задания вы должны применить концепции переобучения и недообучения, кросс-валидации, регуляризации (L1 и L2), а также оценить способность вашей модели к обобщению.
#
# 1. Предварительная обработка данных
# Загрузите данные и проведите их первичный анализ. Очистите данные, если это необходимо, и проведите их нормализацию/стандартизацию.
# Разделите данные на тренировочный и тестовый наборы.
# 2. Обучение модели
#   - Обучите модель логистической регрессии без регуляризации. Оцените её качество на тренировочных и тестовых данных.
#   - Повторите шаг с добавлением L1- и L2-регуляризации. Подберите оптимальные значения параметра регуляризации с помощью кросс-валидации.
# 3. Анализ результатов
#   - Сравните качество всех трёх моделей (без регуляризации, с L1- и с L2-регуляризацией). Как влияют L1 и L2 на качество модели по сравнению с базовой моделью?
#   - Постройте графики кривых обучения для каждой из моделей. Что вы можете сказать о способности ваших моделей к обобщению?
# 4. Отчёт
#   - Подготовьте краткий отчёт, в котором обоснуйте свой выбор параметров для моделей с регуляризацией, объясните полученные результаты и сделайте выводы о качестве моделирования.

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
from catboost import CatBoostClassifier

# %%
X = iris_df.drop('target', axis=1)
Y = iris_df['target']
X_scaled = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, train_size=0.5, random_state = 42)

# %%
model = CatBoostClassifier(iterations=300, learning_rate=0.1, depth=6)
model.fit(X_train, y_train)
# Out:
# 0:	learn: 1.0125218	total: 460us	remaining: 138ms
# 1:	learn: 0.9433466	total: 1.38ms	remaining: 206ms
# 2:	learn: 0.8801573	total: 1.9ms	remaining: 188ms
# 3:	learn: 0.8169726	total: 2.4ms	remaining: 178ms
# 4:	learn: 0.7584521	total: 2.89ms	remaining: 170ms
# 5:	learn: 0.7033068	total: 3.4ms	remaining: 167ms
# 6:	learn: 0.6750187	total: 3.91ms	remaining: 164ms
# 7:	learn: 0.6329005	total: 4.42ms	remaining: 162ms
# 8:	learn: 0.5961354	total: 4.94ms	remaining: 160ms
# 9:	learn: 0.5678646	total: 5.44ms	remaining: 158ms
# 10:	learn: 0.5337200	total: 5.93ms	remaining: 156ms
# 11:	learn: 0.5055587	total: 6.41ms	remaining: 154ms
# 12:	learn: 0.4812175	total: 6.91ms	remaining: 152ms
# 13:	learn: 0.4586960	total: 7.4ms	remaining: 151ms
# 14:	learn: 0.4393754	total: 7.89ms	remaining: 150ms
# 15:	learn: 0.4190304	total: 8.37ms	remaining: 149ms
# 16:	learn: 0.3965629	total: 8.85ms	remaining: 147ms
# 17:	learn: 0.3787514	total: 9.32ms	remaining: 146ms
# 18:	learn: 0.3637709	total: 9.8ms	remaining: 145ms
# 19:	learn: 0.3502088	total: 10.3ms	remaining: 145ms
# 20:	learn: 0.3372897	total: 10.8ms	remaining: 143ms
# 21:	learn: 0.3243463	total: 11.3ms	remaining: 142ms
# 22:	learn: 0.3101664	total: 11.8ms	remaining: 142ms
# 23:	learn: 0.2999872	total: 12.3ms	remaining: 141ms
# 24:	learn: 0.2891209	total: 12.7ms	remaining: 140ms
# 25:	learn: 0.2787024	total: 13.2ms	remaining: 139ms
# 26:	learn: 0.2711765	total: 13.7ms	remaining: 139ms
# 27:	learn: 0.2615539	total: 14.2ms	remaining: 138ms
# 28:	learn: 0.2534765	total: 14.7ms	remaining: 137ms
# 29:	learn: 0.2464462	total: 15.1ms	remaining: 136ms
# 30:	learn: 0.2404518	total: 15.6ms	remaining: 135ms
# 31:	learn: 0.2331878	total: 16.1ms	remaining: 135ms
# 32:	learn: 0.2292846	total: 16.6ms	remaining: 134ms
# 33:	learn: 0.2236389	total: 17.1ms	remaining: 134ms
# 34:	learn: 0.2180537	total: 17.6ms	remaining: 133ms
# 35:	learn: 0.2124300	total: 18.1ms	remaining: 133ms
# 36:	learn: 0.2069760	total: 18.6ms	remaining: 132ms
# 37:	learn: 0.2007888	total: 19ms	remaining: 131ms
# 38:	learn: 0.1954538	total: 19.5ms	remaining: 131ms
# 39:	learn: 0.1903739	total: 20ms	remaining: 130ms
# 40:	learn: 0.1844522	total: 20.4ms	remaining: 129ms
# 41:	learn: 0.1792664	total: 20.9ms	remaining: 128ms
# 42:	learn: 0.1747245	total: 21.4ms	remaining: 128ms
# 43:	learn: 0.1686795	total: 21.9ms	remaining: 127ms
# 44:	learn: 0.1646424	total: 22.4ms	remaining: 127ms
# 45:	learn: 0.1604489	total: 22.9ms	remaining: 126ms
# 46:	learn: 0.1566129	total: 23.3ms	remaining: 126ms
# 47:	learn: 0.1541484	total: 23.8ms	remaining: 125ms
# 48:	learn: 0.1507183	total: 24.3ms	remaining: 124ms
# 49:	learn: 0.1474024	total: 24.8ms	remaining: 124ms
# 50:	learn: 0.1439308	total: 25.3ms	remaining: 123ms
# 51:	learn: 0.1416894	total: 25.7ms	remaining: 123ms
# 52:	learn: 0.1391521	total: 26.4ms	remaining: 123ms
# 53:	learn: 0.1360061	total: 26.9ms	remaining: 123ms
# 54:	learn: 0.1331311	total: 27.4ms	remaining: 122ms
# 55:	learn: 0.1306490	total: 27.9ms	remaining: 122ms
# 56:	learn: 0.1278836	total: 28.4ms	remaining: 121ms
# 57:	learn: 0.1258072	total: 28.9ms	remaining: 120ms
# 58:	learn: 0.1232183	total: 29.4ms	remaining: 120ms
# 59:	learn: 0.1208511	total: 29.9ms	remaining: 120ms
# 60:	learn: 0.1180973	total: 30.4ms	remaining: 119ms
# 61:	learn: 0.1151908	total: 30.9ms	remaining: 118ms
# 62:	learn: 0.1125301	total: 31.4ms	remaining: 118ms
# 63:	learn: 0.1105015	total: 31.9ms	remaining: 118ms
# 64:	learn: 0.1087392	total: 32.6ms	remaining: 118ms
# 65:	learn: 0.1061266	total: 33ms	remaining: 117ms
# 66:	learn: 0.1043688	total: 33.5ms	remaining: 116ms
# 67:	learn: 0.1024427	total: 34.1ms	remaining: 116ms
# 68:	learn: 0.1011162	total: 34.9ms	remaining: 117ms
# 69:	learn: 0.0995754	total: 35.2ms	remaining: 116ms
# 70:	learn: 0.0975033	total: 35.8ms	remaining: 115ms
# 71:	learn: 0.0958706	total: 36.3ms	remaining: 115ms
# 72:	learn: 0.0944554	total: 37.1ms	remaining: 115ms
# 73:	learn: 0.0928882	total: 37.6ms	remaining: 115ms
# 74:	learn: 0.0912581	total: 38.2ms	remaining: 115ms
# 75:	learn: 0.0899821	total: 38.5ms	remaining: 114ms
# 76:	learn: 0.0881395	total: 38.9ms	remaining: 113ms
# 77:	learn: 0.0867543	total: 39.6ms	remaining: 113ms
# 78:	learn: 0.0851813	total: 39.9ms	remaining: 112ms
# 79:	learn: 0.0836468	total: 40.2ms	remaining: 111ms
# 80:	learn: 0.0822007	total: 40.9ms	remaining: 111ms
# 81:	learn: 0.0806411	total: 41.4ms	remaining: 110ms
# 82:	learn: 0.0789712	total: 41.9ms	remaining: 110ms
# 83:	learn: 0.0775308	total: 42.4ms	remaining: 109ms
# 84:	learn: 0.0762782	total: 42.9ms	remaining: 109ms
# 85:	learn: 0.0753932	total: 43.4ms	remaining: 108ms
# 86:	learn: 0.0742852	total: 43.9ms	remaining: 107ms
# 87:	learn: 0.0730704	total: 44.4ms	remaining: 107ms
# 88:	learn: 0.0720927	total: 46.5ms	remaining: 110ms
# 89:	learn: 0.0712423	total: 47.1ms	remaining: 110ms
# 90:	learn: 0.0703705	total: 47.5ms	remaining: 109ms
# 91:	learn: 0.0695107	total: 48.1ms	remaining: 109ms
# 92:	learn: 0.0687789	total: 48.5ms	remaining: 108ms
# 93:	learn: 0.0679996	total: 49ms	remaining: 107ms
# 94:	learn: 0.0671882	total: 49.5ms	remaining: 107ms
# 95:	learn: 0.0665071	total: 50ms	remaining: 106ms
# 96:	learn: 0.0654603	total: 50.5ms	remaining: 106ms
# 97:	learn: 0.0649517	total: 50.9ms	remaining: 105ms
# 98:	learn: 0.0641183	total: 51.3ms	remaining: 104ms
# 99:	learn: 0.0634590	total: 51.8ms	remaining: 104ms
# 100:	learn: 0.0625678	total: 52.3ms	remaining: 103ms
# 101:	learn: 0.0617644	total: 52.8ms	remaining: 102ms
# 102:	learn: 0.0610819	total: 53.3ms	remaining: 102ms
# 103:	learn: 0.0602712	total: 53.7ms	remaining: 101ms
# 104:	learn: 0.0594872	total: 54.2ms	remaining: 101ms
# 105:	learn: 0.0588575	total: 54.7ms	remaining: 100ms
# 106:	learn: 0.0582670	total: 55.1ms	remaining: 99.5ms
# 107:	learn: 0.0576018	total: 55.6ms	remaining: 98.9ms
# 108:	learn: 0.0570241	total: 56.1ms	remaining: 98.3ms
# 109:	learn: 0.0564299	total: 56.5ms	remaining: 97.6ms
# 110:	learn: 0.0557613	total: 57ms	remaining: 97ms
# 111:	learn: 0.0551390	total: 57.4ms	remaining: 96.4ms
# 112:	learn: 0.0545672	total: 57.9ms	remaining: 95.8ms
# 113:	learn: 0.0537667	total: 58.4ms	remaining: 95.3ms
# 114:	learn: 0.0529763	total: 58.9ms	remaining: 94.7ms
# 115:	learn: 0.0525136	total: 59.4ms	remaining: 94.2ms
# 116:	learn: 0.0521782	total: 59.8ms	remaining: 93.6ms
# 117:	learn: 0.0516985	total: 60.3ms	remaining: 93ms
# 118:	learn: 0.0514069	total: 60.8ms	remaining: 92.4ms
# 119:	learn: 0.0507849	total: 61.2ms	remaining: 91.9ms
# 120:	learn: 0.0504320	total: 61.7ms	remaining: 91.3ms
# 121:	learn: 0.0499798	total: 62.2ms	remaining: 90.7ms
# 122:	learn: 0.0494833	total: 62.7ms	remaining: 90.2ms
# 123:	learn: 0.0489807	total: 63.1ms	remaining: 89.6ms
# 124:	learn: 0.0484803	total: 63.6ms	remaining: 89.1ms
# 125:	learn: 0.0480183	total: 64.1ms	remaining: 88.5ms
# 126:	learn: 0.0475101	total: 64.6ms	remaining: 88ms
# 127:	learn: 0.0470763	total: 65.1ms	remaining: 87.5ms
# 128:	learn: 0.0465458	total: 65.6ms	remaining: 86.9ms
# 129:	learn: 0.0461490	total: 66ms	remaining: 86.4ms
# 130:	learn: 0.0455990	total: 66.5ms	remaining: 85.8ms
# 131:	learn: 0.0451433	total: 67ms	remaining: 85.3ms
# 132:	learn: 0.0447807	total: 67.5ms	remaining: 84.7ms
# 133:	learn: 0.0444358	total: 68ms	remaining: 84.2ms
# 134:	learn: 0.0440629	total: 68.4ms	remaining: 83.6ms
# 135:	learn: 0.0436383	total: 68.9ms	remaining: 83.1ms
# 136:	learn: 0.0433332	total: 69.4ms	remaining: 82.5ms
# 137:	learn: 0.0428494	total: 69.9ms	remaining: 82ms
# 138:	learn: 0.0425419	total: 70.4ms	remaining: 81.5ms
# 139:	learn: 0.0421465	total: 70.9ms	remaining: 81ms
# 140:	learn: 0.0417476	total: 71.3ms	remaining: 80.4ms
# 141:	learn: 0.0414251	total: 71.8ms	remaining: 79.9ms
# 142:	learn: 0.0410729	total: 72.2ms	remaining: 79.2ms
# 143:	learn: 0.0407463	total: 72.7ms	remaining: 78.7ms
# 144:	learn: 0.0403304	total: 73.1ms	remaining: 78.2ms
# 145:	learn: 0.0400531	total: 73.6ms	remaining: 77.7ms
# 146:	learn: 0.0397969	total: 74.1ms	remaining: 77.1ms
# 147:	learn: 0.0393977	total: 74.6ms	remaining: 76.6ms
# 148:	learn: 0.0390332	total: 75.1ms	remaining: 76.1ms
# 149:	learn: 0.0386572	total: 75.6ms	remaining: 75.6ms
# 150:	learn: 0.0383637	total: 76.1ms	remaining: 75.1ms
# 151:	learn: 0.0380753	total: 76.6ms	remaining: 74.6ms
# 152:	learn: 0.0377201	total: 77.2ms	remaining: 74.1ms
# 153:	learn: 0.0374832	total: 77.6ms	remaining: 73.6ms
# 154:	learn: 0.0372181	total: 78.1ms	remaining: 73.1ms
# 155:	learn: 0.0370179	total: 78.6ms	remaining: 72.5ms
# 156:	learn: 0.0367204	total: 79.1ms	remaining: 72ms
# 157:	learn: 0.0363470	total: 79.6ms	remaining: 71.5ms
# 158:	learn: 0.0360680	total: 80.1ms	remaining: 71ms
# 159:	learn: 0.0358394	total: 80.6ms	remaining: 70.5ms
# 160:	learn: 0.0356145	total: 81.1ms	remaining: 70ms
# 161:	learn: 0.0354418	total: 81.7ms	remaining: 69.6ms
# 162:	learn: 0.0352461	total: 82.1ms	remaining: 69ms
# 163:	learn: 0.0348885	total: 82.5ms	remaining: 68.5ms
# 164:	learn: 0.0345547	total: 84.5ms	remaining: 69.1ms
# 165:	learn: 0.0343467	total: 85ms	remaining: 68.6ms
# 166:	learn: 0.0341018	total: 85.5ms	remaining: 68.1ms
# 167:	learn: 0.0339061	total: 86ms	remaining: 67.6ms
# 168:	learn: 0.0336647	total: 86.5ms	remaining: 67.1ms
# 169:	learn: 0.0333837	total: 87ms	remaining: 66.5ms
# 170:	learn: 0.0331615	total: 87.3ms	remaining: 65.9ms
# 171:	learn: 0.0328678	total: 87.8ms	remaining: 65.4ms
# 172:	learn: 0.0326374	total: 88.3ms	remaining: 64.8ms
# 173:	learn: 0.0324263	total: 88.8ms	remaining: 64.3ms
# 174:	learn: 0.0322256	total: 89.3ms	remaining: 63.8ms
# 175:	learn: 0.0320202	total: 89.8ms	remaining: 63.2ms
# 176:	learn: 0.0317888	total: 90.2ms	remaining: 62.7ms
# 177:	learn: 0.0316026	total: 90.7ms	remaining: 62.1ms
# 178:	learn: 0.0314111	total: 91.2ms	remaining: 61.6ms
# 179:	learn: 0.0311775	total: 91.6ms	remaining: 61.1ms
# 180:	learn: 0.0310410	total: 92.1ms	remaining: 60.5ms
# 181:	learn: 0.0308652	total: 92.6ms	remaining: 60ms
# 182:	learn: 0.0306040	total: 93.1ms	remaining: 59.5ms
# 183:	learn: 0.0303516	total: 93.5ms	remaining: 58.9ms
# 184:	learn: 0.0301196	total: 94ms	remaining: 58.4ms
# 185:	learn: 0.0299366	total: 94.5ms	remaining: 57.9ms
# 186:	learn: 0.0297184	total: 94.9ms	remaining: 57.4ms
# 187:	learn: 0.0295534	total: 95.4ms	remaining: 56.9ms
# 188:	learn: 0.0293926	total: 95.9ms	remaining: 56.3ms
# 189:	learn: 0.0291800	total: 96.5ms	remaining: 55.8ms
# 190:	learn: 0.0289797	total: 96.9ms	remaining: 55.3ms
# 191:	learn: 0.0287833	total: 97.4ms	remaining: 54.8ms
# 192:	learn: 0.0286101	total: 97.9ms	remaining: 54.3ms
# 193:	learn: 0.0284815	total: 98.4ms	remaining: 53.7ms
# 194:	learn: 0.0282758	total: 98.8ms	remaining: 53.2ms
# 195:	learn: 0.0281149	total: 99.3ms	remaining: 52.7ms
# 196:	learn: 0.0279466	total: 99.7ms	remaining: 52.1ms
# 197:	learn: 0.0277869	total: 100ms	remaining: 51.6ms
# 198:	learn: 0.0276251	total: 101ms	remaining: 51.1ms
# 199:	learn: 0.0275272	total: 101ms	remaining: 50.6ms
# 200:	learn: 0.0273647	total: 102ms	remaining: 50.1ms
# 201:	learn: 0.0271444	total: 102ms	remaining: 49.6ms
# 202:	learn: 0.0270278	total: 103ms	remaining: 49ms
# 203:	learn: 0.0269110	total: 103ms	remaining: 48.5ms
# 204:	learn: 0.0267608	total: 104ms	remaining: 48ms
# 205:	learn: 0.0265770	total: 104ms	remaining: 47.5ms
# 206:	learn: 0.0263990	total: 104ms	remaining: 46.9ms
# 207:	learn: 0.0262607	total: 105ms	remaining: 46.4ms
# 208:	learn: 0.0261157	total: 105ms	remaining: 45.9ms
# 209:	learn: 0.0259705	total: 106ms	remaining: 45.4ms
# 210:	learn: 0.0258789	total: 106ms	remaining: 44.9ms
# 211:	learn: 0.0257442	total: 107ms	remaining: 44.4ms
# 212:	learn: 0.0255985	total: 107ms	remaining: 43.8ms
# 213:	learn: 0.0254743	total: 108ms	remaining: 43.3ms
# 214:	learn: 0.0252861	total: 108ms	remaining: 42.8ms
# 215:	learn: 0.0251304	total: 109ms	remaining: 42.3ms
# 216:	learn: 0.0250057	total: 109ms	remaining: 41.8ms
# 217:	learn: 0.0248992	total: 110ms	remaining: 41.3ms
# 218:	learn: 0.0247141	total: 110ms	remaining: 40.7ms
# 219:	learn: 0.0245928	total: 111ms	remaining: 40.2ms
# 220:	learn: 0.0244570	total: 111ms	remaining: 39.7ms
# 221:	learn: 0.0243125	total: 112ms	remaining: 39.2ms
# 222:	learn: 0.0241924	total: 112ms	remaining: 38.7ms
# 223:	learn: 0.0240752	total: 112ms	remaining: 38.2ms
# 224:	learn: 0.0239232	total: 113ms	remaining: 37.6ms
# 225:	learn: 0.0237703	total: 113ms	remaining: 37.1ms
# 226:	learn: 0.0236359	total: 114ms	remaining: 36.6ms
# 227:	learn: 0.0235283	total: 114ms	remaining: 36.1ms
# 228:	learn: 0.0234148	total: 115ms	remaining: 35.6ms
# 229:	learn: 0.0233230	total: 115ms	remaining: 35.1ms
# 230:	learn: 0.0232270	total: 116ms	remaining: 34.6ms
# 231:	learn: 0.0231229	total: 116ms	remaining: 34.1ms
# 232:	learn: 0.0230354	total: 117ms	remaining: 33.6ms
# 233:	learn: 0.0229005	total: 117ms	remaining: 33ms
# 234:	learn: 0.0227744	total: 118ms	remaining: 32.6ms
# 235:	learn: 0.0226666	total: 118ms	remaining: 32.1ms
# 236:	learn: 0.0225749	total: 119ms	remaining: 31.5ms
# 237:	learn: 0.0224908	total: 119ms	remaining: 31ms
# 238:	learn: 0.0223951	total: 120ms	remaining: 30.5ms
# 239:	learn: 0.0222370	total: 120ms	remaining: 30.1ms
# 240:	learn: 0.0221397	total: 121ms	remaining: 29.6ms
# 241:	learn: 0.0220374	total: 122ms	remaining: 29.2ms
# 242:	learn: 0.0219221	total: 122ms	remaining: 28.6ms
# 243:	learn: 0.0218262	total: 123ms	remaining: 28.2ms
# 244:	learn: 0.0217330	total: 123ms	remaining: 27.7ms
# 245:	learn: 0.0216328	total: 124ms	remaining: 27.2ms
# 246:	learn: 0.0215310	total: 124ms	remaining: 26.7ms
# 247:	learn: 0.0214215	total: 125ms	remaining: 26.1ms
# 248:	learn: 0.0212821	total: 125ms	remaining: 25.6ms
# 249:	learn: 0.0211653	total: 126ms	remaining: 25.2ms
# 250:	learn: 0.0211058	total: 126ms	remaining: 24.7ms
# 251:	learn: 0.0210119	total: 127ms	remaining: 24.2ms
# 252:	learn: 0.0209265	total: 127ms	remaining: 23.6ms
# 253:	learn: 0.0208270	total: 128ms	remaining: 23.1ms
# 254:	learn: 0.0207484	total: 128ms	remaining: 22.6ms
# 255:	learn: 0.0206416	total: 129ms	remaining: 22.1ms
# 256:	learn: 0.0205534	total: 129ms	remaining: 21.6ms
# 257:	learn: 0.0204657	total: 130ms	remaining: 21.1ms
# 258:	learn: 0.0203696	total: 130ms	remaining: 20.6ms
# 259:	learn: 0.0202733	total: 131ms	remaining: 20.1ms
# 260:	learn: 0.0201944	total: 131ms	remaining: 19.6ms
# 261:	learn: 0.0201335	total: 132ms	remaining: 19.1ms
# 262:	learn: 0.0200462	total: 132ms	remaining: 18.6ms
# 263:	learn: 0.0199734	total: 132ms	remaining: 18.1ms
# 264:	learn: 0.0198922	total: 133ms	remaining: 17.6ms
# 265:	learn: 0.0198070	total: 133ms	remaining: 17ms
# 266:	learn: 0.0197166	total: 134ms	remaining: 16.5ms
# 267:	learn: 0.0196378	total: 134ms	remaining: 16ms
# 268:	learn: 0.0195400	total: 135ms	remaining: 15.5ms
# 269:	learn: 0.0194506	total: 135ms	remaining: 15ms
# 270:	learn: 0.0193851	total: 136ms	remaining: 14.5ms
# 271:	learn: 0.0193111	total: 136ms	remaining: 14ms
# 272:	learn: 0.0192318	total: 137ms	remaining: 13.5ms
# 273:	learn: 0.0191468	total: 137ms	remaining: 13ms
# 274:	learn: 0.0190847	total: 138ms	remaining: 12.5ms
# 275:	learn: 0.0190089	total: 138ms	remaining: 12ms
# 276:	learn: 0.0189206	total: 139ms	remaining: 11.5ms
# 277:	learn: 0.0188380	total: 139ms	remaining: 11ms
# 278:	learn: 0.0187572	total: 139ms	remaining: 10.5ms
# 279:	learn: 0.0186833	total: 140ms	remaining: 10ms
# 280:	learn: 0.0186222	total: 140ms	remaining: 9.5ms
# 281:	learn: 0.0185486	total: 141ms	remaining: 8.99ms
# 282:	learn: 0.0184790	total: 141ms	remaining: 8.49ms
# 283:	learn: 0.0183801	total: 142ms	remaining: 7.99ms
# 284:	learn: 0.0182999	total: 142ms	remaining: 7.49ms
# 285:	learn: 0.0182427	total: 143ms	remaining: 6.99ms
# 286:	learn: 0.0181917	total: 143ms	remaining: 6.49ms
# 287:	learn: 0.0181183	total: 144ms	remaining: 5.99ms
# 288:	learn: 0.0180276	total: 144ms	remaining: 5.49ms
# 289:	learn: 0.0179494	total: 145ms	remaining: 4.99ms
# 290:	learn: 0.0178878	total: 145ms	remaining: 4.49ms
# 291:	learn: 0.0178199	total: 146ms	remaining: 3.99ms
# 292:	learn: 0.0177335	total: 146ms	remaining: 3.49ms
# 293:	learn: 0.0176721	total: 146ms	remaining: 2.99ms
# 294:	learn: 0.0176199	total: 147ms	remaining: 2.49ms
# 295:	learn: 0.0175652	total: 147ms	remaining: 1.99ms
# 296:	learn: 0.0175015	total: 148ms	remaining: 1.49ms
# 297:	learn: 0.0174300	total: 148ms	remaining: 996us
# 298:	learn: 0.0173601	total: 149ms	remaining: 498us
# 299:	learn: 0.0173018	total: 149ms	remaining: 0us

# %%
accuracy = model.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9733333333333334

# %%
# Однократная оценка на тестовых данных
single_score = accuracy_score(y_test, model.predict(X_test))
print("Однократная оценка эффективности (accuracy):", single_score)

# 5-кратная кросс-валидация на всем датасете
cross_val_scores = cross_val_score(model, X, Y, cv=5, scoring='accuracy')
print("Среднее значение accuracy по 5-кратной кросс-валидации:", cross_val_scores.mean())

scores_10 = cross_val_score(model, X, Y, cv=10, scoring='accuracy')
print("Среднее значение accuracy при 10-кратной кросс-валидации:", scores_10.mean())
# Out:
# Однократная оценка эффективности (accuracy): 0.9733333333333334
# 0:	learn: 0.9803757	total: 631us	remaining: 189ms
# 1:	learn: 0.8844459	total: 1.4ms	remaining: 208ms
# 2:	learn: 0.8085838	total: 1.74ms	remaining: 173ms
# 3:	learn: 0.7324438	total: 2.06ms	remaining: 153ms
# 4:	learn: 0.6750169	total: 2.92ms	remaining: 173ms
# 5:	learn: 0.6155895	total: 3.25ms	remaining: 159ms
# 6:	learn: 0.5789933	total: 3.37ms	remaining: 141ms
# 7:	learn: 0.5384419	total: 3.68ms	remaining: 134ms
# 8:	learn: 0.5051148	total: 4.61ms	remaining: 149ms
# 9:	learn: 0.4750354	total: 5.14ms	remaining: 149ms
# 10:	learn: 0.4410862	total: 5.67ms	remaining: 149ms
# 11:	learn: 0.4164147	total: 6.2ms	remaining: 149ms
# 12:	learn: 0.3906128	total: 6.72ms	remaining: 148ms
# 13:	learn: 0.3677930	total: 7.25ms	remaining: 148ms
# 14:	learn: 0.3495499	total: 7.74ms	remaining: 147ms
# 15:	learn: 0.3332474	total: 8.26ms	remaining: 147ms
# 16:	learn: 0.3159302	total: 8.79ms	remaining: 146ms
# 17:	learn: 0.3002333	total: 9.29ms	remaining: 146ms
# 18:	learn: 0.2852627	total: 9.71ms	remaining: 144ms
# 19:	learn: 0.2725787	total: 10.2ms	remaining: 143ms
# 20:	learn: 0.2604872	total: 10.7ms	remaining: 142ms
# 21:	learn: 0.2493693	total: 11.2ms	remaining: 142ms
# 22:	learn: 0.2380611	total: 11.7ms	remaining: 141ms
# 23:	learn: 0.2303653	total: 12.3ms	remaining: 141ms
# 24:	learn: 0.2225129	total: 12.8ms	remaining: 141ms
# 25:	learn: 0.2143033	total: 13.2ms	remaining: 139ms
# 26:	learn: 0.2057984	total: 13.9ms	remaining: 140ms
# 27:	learn: 0.1987355	total: 14.8ms	remaining: 144ms
# 28:	learn: 0.1913064	total: 15.4ms	remaining: 144ms
# 29:	learn: 0.1847782	total: 16ms	remaining: 144ms
# 30:	learn: 0.1800523	total: 16.5ms	remaining: 143ms
# 31:	learn: 0.1767956	total: 17ms	remaining: 143ms
# 32:	learn: 0.1705645	total: 17.6ms	remaining: 142ms
# 33:	learn: 0.1671014	total: 18.1ms	remaining: 141ms
# 34:	learn: 0.1612533	total: 18.6ms	remaining: 141ms
# 35:	learn: 0.1571880	total: 19.1ms	remaining: 140ms
# 36:	learn: 0.1519270	total: 19.5ms	remaining: 138ms
# 37:	learn: 0.1479053	total: 20ms	remaining: 138ms
# 38:	learn: 0.1441377	total: 20.5ms	remaining: 137ms
# 39:	learn: 0.1410196	total: 21.1ms	remaining: 137ms
# 40:	learn: 0.1374328	total: 21.6ms	remaining: 136ms
# 41:	learn: 0.1344350	total: 22.1ms	remaining: 136ms
# 42:	learn: 0.1309708	total: 22.6ms	remaining: 135ms
# 43:	learn: 0.1281806	total: 23.1ms	remaining: 135ms
# 44:	learn: 0.1248295	total: 24.2ms	remaining: 137ms
# 45:	learn: 0.1217349	total: 25.2ms	remaining: 139ms
# 46:	learn: 0.1191088	total: 25.8ms	remaining: 139ms
# 47:	learn: 0.1171241	total: 26.3ms	remaining: 138ms
# 48:	learn: 0.1143586	total: 26.8ms	remaining: 137ms
# 49:	learn: 0.1121308	total: 27.4ms	remaining: 137ms
# 50:	learn: 0.1089723	total: 27.9ms	remaining: 136ms
# 51:	learn: 0.1050921	total: 28.4ms	remaining: 135ms
# 52:	learn: 0.1026474	total: 28.9ms	remaining: 135ms
# 53:	learn: 0.1003139	total: 29.9ms	remaining: 136ms
# 54:	learn: 0.0978366	total: 30.7ms	remaining: 137ms
# 55:	learn: 0.0962393	total: 31.4ms	remaining: 137ms
# 56:	learn: 0.0943132	total: 32ms	remaining: 136ms
# 57:	learn: 0.0920249	total: 32.6ms	remaining: 136ms
# 58:	learn: 0.0905843	total: 33.2ms	remaining: 136ms
# 59:	learn: 0.0886806	total: 33.7ms	remaining: 135ms
# 60:	learn: 0.0867759	total: 34.3ms	remaining: 134ms
# 61:	learn: 0.0846059	total: 34.8ms	remaining: 134ms
# 62:	learn: 0.0830208	total: 35.3ms	remaining: 133ms
# 63:	learn: 0.0818089	total: 35.8ms	remaining: 132ms
# 64:	learn: 0.0796899	total: 36.3ms	remaining: 131ms
# 65:	learn: 0.0783070	total: 36.9ms	remaining: 131ms
# 66:	learn: 0.0768795	total: 37.3ms	remaining: 130ms
# 67:	learn: 0.0757340	total: 37.9ms	remaining: 129ms
# 68:	learn: 0.0742067	total: 38.4ms	remaining: 128ms
# 69:	learn: 0.0726206	total: 38.9ms	remaining: 128ms
# 70:	learn: 0.0708314	total: 39.4ms	remaining: 127ms
# 71:	learn: 0.0694501	total: 39.9ms	remaining: 126ms
# 72:	learn: 0.0679667	total: 40.4ms	remaining: 125ms
# 73:	learn: 0.0668903	total: 40.9ms	remaining: 125ms
# 74:	learn: 0.0652203	total: 41.4ms	remaining: 124ms
# 75:	learn: 0.0641923	total: 41.9ms	remaining: 123ms
# 76:	learn: 0.0627051	total: 42.4ms	remaining: 123ms
# 77:	learn: 0.0618245	total: 42.9ms	remaining: 122ms
# 78:	learn: 0.0605969	total: 43.4ms	remaining: 121ms
# 79:	learn: 0.0593997	total: 43.9ms	remaining: 121ms
# 80:	learn: 0.0583721	total: 44.4ms	remaining: 120ms
# 81:	learn: 0.0573764	total: 44.9ms	remaining: 119ms
# 82:	learn: 0.0561274	total: 45.4ms	remaining: 119ms
# 83:	learn: 0.0553621	total: 45.9ms	remaining: 118ms
# 84:	learn: 0.0546956	total: 46.4ms	remaining: 117ms
# 85:	learn: 0.0538159	total: 46.9ms	remaining: 117ms
# 86:	learn: 0.0532406	total: 47.4ms	remaining: 116ms
# 87:	learn: 0.0524498	total: 47.9ms	remaining: 116ms
# 88:	learn: 0.0518034	total: 48.4ms	remaining: 115ms
# 89:	learn: 0.0509753	total: 48.9ms	remaining: 114ms
# 90:	learn: 0.0501939	total: 49.4ms	remaining: 114ms
# 91:	learn: 0.0491118	total: 49.9ms	remaining: 113ms
# 92:	learn: 0.0483291	total: 50.4ms	remaining: 112ms
# 93:	learn: 0.0475877	total: 51ms	remaining: 112ms
# 94:	learn: 0.0470237	total: 51.5ms	remaining: 111ms
# 95:	learn: 0.0462271	total: 52ms	remaining: 110ms
# 96:	learn: 0.0455771	total: 52.5ms	remaining: 110ms
# 97:	learn: 0.0447550	total: 53ms	remaining: 109ms
# 98:	learn: 0.0441306	total: 53.5ms	remaining: 109ms
# 99:	learn: 0.0435463	total: 54ms	remaining: 108ms
# 100:	learn: 0.0430833	total: 54.5ms	remaining: 107ms
# 101:	learn: 0.0424997	total: 55.1ms	remaining: 107ms
# 102:	learn: 0.0417286	total: 55.6ms	remaining: 106ms
# 103:	learn: 0.0411709	total: 56ms	remaining: 106ms
# 104:	learn: 0.0408208	total: 56.5ms	remaining: 105ms
# 105:	learn: 0.0404885	total: 57.1ms	remaining: 104ms
# 106:	learn: 0.0400237	total: 57.6ms	remaining: 104ms
# 107:	learn: 0.0396171	total: 58.2ms	remaining: 103ms
# 108:	learn: 0.0390486	total: 58.7ms	remaining: 103ms
# 109:	learn: 0.0384547	total: 59.4ms	remaining: 103ms
# 110:	learn: 0.0380388	total: 60ms	remaining: 102ms
# 111:	learn: 0.0376550	total: 60.6ms	remaining: 102ms
# 112:	learn: 0.0372511	total: 61.1ms	remaining: 101ms
# 113:	learn: 0.0368711	total: 61.7ms	remaining: 101ms
# 114:	learn: 0.0365231	total: 62.2ms	remaining: 100ms
# 115:	learn: 0.0360909	total: 62.7ms	remaining: 99.4ms
# 116:	learn: 0.0356201	total: 63.2ms	remaining: 98.8ms
# 117:	learn: 0.0352076	total: 63.7ms	remaining: 98.2ms
# 118:	learn: 0.0347143	total: 64.2ms	remaining: 97.6ms
# 119:	learn: 0.0343847	total: 64.7ms	remaining: 97.1ms
# 120:	learn: 0.0340465	total: 65.2ms	remaining: 96.5ms
# 121:	learn: 0.0335916	total: 65.8ms	remaining: 96ms
# 122:	learn: 0.0332822	total: 66.3ms	remaining: 95.4ms
# 123:	learn: 0.0329250	total: 66.8ms	remaining: 94.8ms
# 124:	learn: 0.0326236	total: 67.3ms	remaining: 94.3ms
# 125:	learn: 0.0322397	total: 67.8ms	remaining: 93.7ms
# 126:	learn: 0.0319147	total: 68.4ms	remaining: 93.1ms
# 127:	learn: 0.0316060	total: 68.8ms	remaining: 92.5ms
# 128:	learn: 0.0313171	total: 69.3ms	remaining: 91.9ms
# 129:	learn: 0.0310858	total: 69.9ms	remaining: 91.4ms
# 130:	learn: 0.0306596	total: 70.4ms	remaining: 90.8ms
# 131:	learn: 0.0303331	total: 70.9ms	remaining: 90.2ms
# 132:	learn: 0.0300019	total: 71.4ms	remaining: 89.6ms
# 133:	learn: 0.0295756	total: 71.9ms	remaining: 89.1ms
# 134:	learn: 0.0293673	total: 72.4ms	remaining: 88.5ms
# 135:	learn: 0.0290583	total: 72.9ms	remaining: 88ms
# 136:	learn: 0.0288009	total: 73.5ms	remaining: 87.4ms
# 137:	learn: 0.0285318	total: 73.9ms	remaining: 86.8ms
# 138:	learn: 0.0282961	total: 74.6ms	remaining: 86.4ms
# 139:	learn: 0.0280578	total: 75.1ms	remaining: 85.8ms
# 140:	learn: 0.0278299	total: 75.5ms	remaining: 85.2ms
# 141:	learn: 0.0276798	total: 76.1ms	remaining: 84.6ms
# 142:	learn: 0.0274534	total: 76.6ms	remaining: 84.1ms
# 143:	learn: 0.0272176	total: 77.1ms	remaining: 83.5ms
# 144:	learn: 0.0269724	total: 77.6ms	remaining: 82.9ms
# 145:	learn: 0.0266532	total: 78.1ms	remaining: 82.3ms
# 146:	learn: 0.0264074	total: 79.1ms	remaining: 82.3ms
# 147:	learn: 0.0262522	total: 79.9ms	remaining: 82ms
# 148:	learn: 0.0260532	total: 80.5ms	remaining: 81.6ms
# 149:	learn: 0.0258478	total: 81ms	remaining: 81ms
# 150:	learn: 0.0256424	total: 81.5ms	remaining: 80.4ms
# 151:	learn: 0.0254673	total: 82ms	remaining: 79.9ms
# 152:	learn: 0.0252992	total: 82.5ms	remaining: 79.3ms
# 153:	learn: 0.0250818	total: 83ms	remaining: 78.7ms
# 154:	learn: 0.0248660	total: 83.6ms	remaining: 78.2ms
# 155:	learn: 0.0247051	total: 84.1ms	remaining: 77.6ms
# 156:	learn: 0.0245147	total: 84.6ms	remaining: 77ms
# 157:	learn: 0.0242863	total: 85.1ms	remaining: 76.5ms
# 158:	learn: 0.0240809	total: 85.6ms	remaining: 75.9ms
# 159:	learn: 0.0239073	total: 86.1ms	remaining: 75.4ms
# 160:	learn: 0.0237183	total: 86.6ms	remaining: 74.8ms
# 161:	learn: 0.0235947	total: 87.1ms	remaining: 74.2ms
# 162:	learn: 0.0233495	total: 87.6ms	remaining: 73.7ms
# 163:	learn: 0.0231928	total: 88.2ms	remaining: 73.1ms
# 164:	learn: 0.0230654	total: 88.6ms	remaining: 72.5ms
# 165:	learn: 0.0228899	total: 89.2ms	remaining: 72ms
# 166:	learn: 0.0227125	total: 89.7ms	remaining: 71.4ms
# 167:	learn: 0.0225247	total: 90.2ms	remaining: 70.9ms
# 168:	learn: 0.0223329	total: 90.7ms	remaining: 70.3ms
# 169:	learn: 0.0221399	total: 91.2ms	remaining: 69.8ms
# 170:	learn: 0.0219702	total: 91.7ms	remaining: 69.2ms
# 171:	learn: 0.0218566	total: 92.2ms	remaining: 68.6ms
# 172:	learn: 0.0217233	total: 92.7ms	remaining: 68ms
# 173:	learn: 0.0215792	total: 93.2ms	remaining: 67.5ms
# 174:	learn: 0.0214285	total: 93.7ms	remaining: 66.9ms
# 175:	learn: 0.0212682	total: 94.2ms	remaining: 66.4ms
# 176:	learn: 0.0211312	total: 94.7ms	remaining: 65.8ms
# 177:	learn: 0.0209912	total: 95.2ms	remaining: 65.3ms
# 178:	learn: 0.0208511	total: 95.7ms	remaining: 64.7ms
# 179:	learn: 0.0206747	total: 96.2ms	remaining: 64.1ms
# 180:	learn: 0.0204748	total: 96.7ms	remaining: 63.6ms
# 181:	learn: 0.0203503	total: 97.2ms	remaining: 63ms
# 182:	learn: 0.0202534	total: 97.7ms	remaining: 62.5ms
# 183:	learn: 0.0201094	total: 98.3ms	remaining: 61.9ms
# 184:	learn: 0.0200020	total: 98.8ms	remaining: 61.4ms
# 185:	learn: 0.0198838	total: 99.2ms	remaining: 60.8ms
# 186:	learn: 0.0197426	total: 99.8ms	remaining: 60.3ms
# 187:	learn: 0.0196418	total: 100ms	remaining: 59.8ms
# 188:	learn: 0.0195119	total: 101ms	remaining: 59.2ms
# 189:	learn: 0.0193737	total: 101ms	remaining: 58.7ms
# 190:	learn: 0.0192726	total: 102ms	remaining: 58.1ms
# 191:	learn: 0.0191467	total: 102ms	remaining: 57.6ms
# 192:	learn: 0.0190225	total: 103ms	remaining: 57ms
# 193:	learn: 0.0189239	total: 103ms	remaining: 56.5ms
# 194:	learn: 0.0188274	total: 104ms	remaining: 55.9ms
# 195:	learn: 0.0187073	total: 104ms	remaining: 55.4ms
# 196:	learn: 0.0185895	total: 105ms	remaining: 54.8ms
# 197:	learn: 0.0184736	total: 105ms	remaining: 54.3ms
# 198:	learn: 0.0183601	total: 106ms	remaining: 53.7ms
# 199:	learn: 0.0182553	total: 106ms	remaining: 53.2ms
# 200:	learn: 0.0181194	total: 107ms	remaining: 52.6ms
# 201:	learn: 0.0180147	total: 107ms	remaining: 52.1ms
# 202:	learn: 0.0178611	total: 108ms	remaining: 51.5ms
# 203:	learn: 0.0177092	total: 108ms	remaining: 51ms
# 204:	learn: 0.0176151	total: 109ms	remaining: 50.4ms
# 205:	learn: 0.0175472	total: 109ms	remaining: 49.9ms
# 206:	learn: 0.0174520	total: 110ms	remaining: 49.3ms
# 207:	learn: 0.0173526	total: 110ms	remaining: 48.8ms
# 208:	learn: 0.0172573	total: 111ms	remaining: 48.2ms
# 209:	learn: 0.0171581	total: 111ms	remaining: 47.7ms
# 210:	learn: 0.0170750	total: 112ms	remaining: 47.1ms
# 211:	learn: 0.0169881	total: 112ms	remaining: 46.6ms
# 212:	learn: 0.0169011	total: 113ms	remaining: 46.1ms
# 213:	learn: 0.0168427	total: 113ms	remaining: 45.5ms
# 214:	learn: 0.0167267	total: 114ms	remaining: 45ms
# 215:	learn: 0.0166173	total: 114ms	remaining: 44.4ms
# 216:	learn: 0.0165330	total: 115ms	remaining: 43.9ms
# 217:	learn: 0.0164230	total: 115ms	remaining: 43.4ms
# 218:	learn: 0.0163525	total: 116ms	remaining: 42.8ms
# 219:	learn: 0.0162775	total: 116ms	remaining: 42.3ms
# 220:	learn: 0.0161841	total: 117ms	remaining: 41.7ms
# 221:	learn: 0.0161038	total: 117ms	remaining: 41.2ms
# 222:	learn: 0.0160169	total: 118ms	remaining: 40.7ms
# 223:	learn: 0.0159222	total: 118ms	remaining: 40.1ms
# 224:	learn: 0.0158357	total: 119ms	remaining: 39.6ms
# 225:	learn: 0.0157772	total: 119ms	remaining: 39.1ms
# 226:	learn: 0.0157007	total: 120ms	remaining: 38.5ms
# 227:	learn: 0.0155835	total: 120ms	remaining: 38ms
# 228:	learn: 0.0154937	total: 121ms	remaining: 37.5ms
# 229:	learn: 0.0154052	total: 121ms	remaining: 36.9ms
# 230:	learn: 0.0153445	total: 122ms	remaining: 36.4ms
# 231:	learn: 0.0152914	total: 122ms	remaining: 35.9ms
# 232:	learn: 0.0152150	total: 123ms	remaining: 35.3ms
# 233:	learn: 0.0151452	total: 123ms	remaining: 34.8ms
# 234:	learn: 0.0150564	total: 124ms	remaining: 34.2ms
# 235:	learn: 0.0149873	total: 124ms	remaining: 33.7ms
# 236:	learn: 0.0148663	total: 125ms	remaining: 33.2ms
# 237:	learn: 0.0147831	total: 125ms	remaining: 32.7ms
# 238:	learn: 0.0147212	total: 126ms	remaining: 32.2ms
# 239:	learn: 0.0146222	total: 127ms	remaining: 31.6ms
# 240:	learn: 0.0145547	total: 127ms	remaining: 31.1ms
# 241:	learn: 0.0144614	total: 128ms	remaining: 30.6ms
# 242:	learn: 0.0143729	total: 128ms	remaining: 30ms
# 243:	learn: 0.0143150	total: 129ms	remaining: 29.5ms
# 244:	learn: 0.0142293	total: 129ms	remaining: 29ms
# 245:	learn: 0.0141541	total: 130ms	remaining: 28.5ms
# 246:	learn: 0.0140930	total: 130ms	remaining: 27.9ms
# 247:	learn: 0.0140238	total: 131ms	remaining: 27.4ms
# 248:	learn: 0.0139783	total: 131ms	remaining: 26.9ms
# 249:	learn: 0.0138991	total: 132ms	remaining: 26.3ms
# 250:	learn: 0.0138457	total: 132ms	remaining: 25.8ms
# 251:	learn: 0.0137867	total: 133ms	remaining: 25.3ms
# 252:	learn: 0.0137324	total: 133ms	remaining: 24.7ms
# 253:	learn: 0.0136798	total: 134ms	remaining: 24.2ms
# 254:	learn: 0.0136368	total: 135ms	remaining: 23.8ms
# 255:	learn: 0.0135527	total: 136ms	remaining: 23.3ms
# 256:	learn: 0.0134970	total: 136ms	remaining: 22.8ms
# 257:	learn: 0.0134478	total: 137ms	remaining: 22.3ms
# 258:	learn: 0.0133837	total: 137ms	remaining: 21.7ms
# 259:	learn: 0.0133133	total: 138ms	remaining: 21.2ms
# 260:	learn: 0.0132541	total: 138ms	remaining: 20.7ms
# 261:	learn: 0.0131981	total: 139ms	remaining: 20.1ms
# 262:	learn: 0.0131564	total: 139ms	remaining: 19.6ms
# 263:	learn: 0.0131038	total: 140ms	remaining: 19.1ms
# 264:	learn: 0.0130453	total: 140ms	remaining: 18.5ms
# 265:	learn: 0.0129868	total: 141ms	remaining: 18ms
# 266:	learn: 0.0129269	total: 141ms	remaining: 17.5ms
# 267:	learn: 0.0128724	total: 142ms	remaining: 16.9ms
# 268:	learn: 0.0127988	total: 142ms	remaining: 16.4ms
# 269:	learn: 0.0127505	total: 143ms	remaining: 15.9ms
# 270:	learn: 0.0127064	total: 143ms	remaining: 15.4ms
# 271:	learn: 0.0126561	total: 144ms	remaining: 14.8ms
# 272:	learn: 0.0126213	total: 145ms	remaining: 14.3ms
# 273:	learn: 0.0125614	total: 147ms	remaining: 13.9ms
# 274:	learn: 0.0125044	total: 148ms	remaining: 13.4ms
# 275:	learn: 0.0124524	total: 148ms	remaining: 12.9ms
# 276:	learn: 0.0124074	total: 149ms	remaining: 12.3ms
# 277:	learn: 0.0123602	total: 149ms	remaining: 11.8ms
# 278:	learn: 0.0123204	total: 150ms	remaining: 11.3ms
# 279:	learn: 0.0122721	total: 150ms	remaining: 10.7ms
# 280:	learn: 0.0122304	total: 151ms	remaining: 10.2ms
# 281:	learn: 0.0121607	total: 152ms	remaining: 9.68ms
# 282:	learn: 0.0121082	total: 152ms	remaining: 9.14ms
# 283:	learn: 0.0120715	total: 153ms	remaining: 8.61ms
# 284:	learn: 0.0120220	total: 153ms	remaining: 8.07ms
# 285:	learn: 0.0119714	total: 154ms	remaining: 7.53ms
# 286:	learn: 0.0119221	total: 154ms	remaining: 6.99ms
# 287:	learn: 0.0118772	total: 155ms	remaining: 6.45ms
# 288:	learn: 0.0118286	total: 155ms	remaining: 5.91ms
# 289:	learn: 0.0117820	total: 156ms	remaining: 5.38ms
# 290:	learn: 0.0117217	total: 156ms	remaining: 4.84ms
# 291:	learn: 0.0116918	total: 157ms	remaining: 4.3ms
# 292:	learn: 0.0116567	total: 157ms	remaining: 3.76ms
# 293:	learn: 0.0116128	total: 158ms	remaining: 3.22ms
# 294:	learn: 0.0115515	total: 159ms	remaining: 2.69ms
# 295:	learn: 0.0115183	total: 159ms	remaining: 2.15ms
# 296:	learn: 0.0114789	total: 160ms	remaining: 1.61ms
# 297:	learn: 0.0114440	total: 160ms	remaining: 1.07ms
# 298:	learn: 0.0113914	total: 161ms	remaining: 537us
# 299:	learn: 0.0113470	total: 161ms	remaining: 0us
# 0:	learn: 0.9785710	total: 426us	remaining: 128ms
# 1:	learn: 0.8864243	total: 1.36ms	remaining: 203ms
# 2:	learn: 0.8141437	total: 1.96ms	remaining: 194ms
# 3:	learn: 0.7457894	total: 2.48ms	remaining: 183ms
# 4:	learn: 0.6873670	total: 3.02ms	remaining: 178ms
# 5:	learn: 0.6322279	total: 3.52ms	remaining: 172ms
# 6:	learn: 0.5897978	total: 4.04ms	remaining: 169ms
# 7:	learn: 0.5465394	total: 4.53ms	remaining: 165ms
# 8:	learn: 0.5086633	total: 5.04ms	remaining: 163ms
# 9:	learn: 0.4734673	total: 5.54ms	remaining: 161ms
# 10:	learn: 0.4399589	total: 6.04ms	remaining: 159ms
# 11:	learn: 0.4139745	total: 6.56ms	remaining: 158ms
# 12:	learn: 0.3886544	total: 7.06ms	remaining: 156ms
# 13:	learn: 0.3653236	total: 7.58ms	remaining: 155ms
# 14:	learn: 0.3483267	total: 8.07ms	remaining: 153ms
# 15:	learn: 0.3311585	total: 8.57ms	remaining: 152ms
# 16:	learn: 0.3149011	total: 9.09ms	remaining: 151ms
# 17:	learn: 0.2988766	total: 9.6ms	remaining: 150ms
# 18:	learn: 0.2854729	total: 10.2ms	remaining: 151ms
# 19:	learn: 0.2723973	total: 10.7ms	remaining: 150ms
# 20:	learn: 0.2611320	total: 11.2ms	remaining: 149ms
# 21:	learn: 0.2508647	total: 11.7ms	remaining: 148ms
# 22:	learn: 0.2392750	total: 12.2ms	remaining: 147ms
# 23:	learn: 0.2302405	total: 12.7ms	remaining: 146ms
# 24:	learn: 0.2224896	total: 13.2ms	remaining: 145ms
# 25:	learn: 0.2137370	total: 13.7ms	remaining: 144ms
# 26:	learn: 0.2073887	total: 14.2ms	remaining: 144ms
# 27:	learn: 0.1999449	total: 14.7ms	remaining: 143ms
# 28:	learn: 0.1929373	total: 15.2ms	remaining: 142ms
# 29:	learn: 0.1850097	total: 15.8ms	remaining: 142ms
# 30:	learn: 0.1781133	total: 16.2ms	remaining: 140ms
# 31:	learn: 0.1716361	total: 16.8ms	remaining: 141ms
# 32:	learn: 0.1674957	total: 17.7ms	remaining: 143ms
# 33:	learn: 0.1628086	total: 18.3ms	remaining: 143ms
# 34:	learn: 0.1594424	total: 18.8ms	remaining: 143ms
# 35:	learn: 0.1543181	total: 19.4ms	remaining: 142ms
# 36:	learn: 0.1496484	total: 19.9ms	remaining: 141ms
# 37:	learn: 0.1459234	total: 20.4ms	remaining: 141ms
# 38:	learn: 0.1429049	total: 20.9ms	remaining: 140ms
# 39:	learn: 0.1391707	total: 21.4ms	remaining: 139ms
# 40:	learn: 0.1368835	total: 21.9ms	remaining: 139ms
# 41:	learn: 0.1336625	total: 22.2ms	remaining: 137ms
# 42:	learn: 0.1311605	total: 22.7ms	remaining: 136ms
# 43:	learn: 0.1282286	total: 23.2ms	remaining: 135ms
# 44:	learn: 0.1250111	total: 23.7ms	remaining: 134ms
# 45:	learn: 0.1224590	total: 24.2ms	remaining: 134ms
# 46:	learn: 0.1195871	total: 24.7ms	remaining: 133ms
# 47:	learn: 0.1164715	total: 25.2ms	remaining: 132ms
# 48:	learn: 0.1146129	total: 25.7ms	remaining: 132ms
# 49:	learn: 0.1122142	total: 26.2ms	remaining: 131ms
# 50:	learn: 0.1093111	total: 26.7ms	remaining: 130ms
# 51:	learn: 0.1074507	total: 27.2ms	remaining: 130ms
# 52:	learn: 0.1055106	total: 27.6ms	remaining: 129ms
# 53:	learn: 0.1030038	total: 28.2ms	remaining: 128ms
# 54:	learn: 0.1008912	total: 28.6ms	remaining: 128ms
# 55:	learn: 0.0984323	total: 29.1ms	remaining: 127ms
# 56:	learn: 0.0964853	total: 29.6ms	remaining: 126ms
# 57:	learn: 0.0945131	total: 30.3ms	remaining: 126ms
# 58:	learn: 0.0920915	total: 30.8ms	remaining: 126ms
# 59:	learn: 0.0907155	total: 31.4ms	remaining: 125ms
# 60:	learn: 0.0894912	total: 31.9ms	remaining: 125ms
# 61:	learn: 0.0874626	total: 32.4ms	remaining: 125ms
# 62:	learn: 0.0854395	total: 33ms	remaining: 124ms
# 63:	learn: 0.0840206	total: 33.5ms	remaining: 123ms
# 64:	learn: 0.0824936	total: 34ms	remaining: 123ms
# 65:	learn: 0.0810660	total: 34.5ms	remaining: 122ms
# 66:	learn: 0.0791075	total: 35ms	remaining: 122ms
# 67:	learn: 0.0778737	total: 35.5ms	remaining: 121ms
# 68:	learn: 0.0765816	total: 36ms	remaining: 121ms
# 69:	learn: 0.0750440	total: 36.5ms	remaining: 120ms
# 70:	learn: 0.0736734	total: 37.1ms	remaining: 120ms
# 71:	learn: 0.0724900	total: 37.6ms	remaining: 119ms
# 72:	learn: 0.0715386	total: 38.1ms	remaining: 118ms
# 73:	learn: 0.0704226	total: 38.6ms	remaining: 118ms
# 74:	learn: 0.0694045	total: 39.1ms	remaining: 117ms
# 75:	learn: 0.0682834	total: 39.6ms	remaining: 117ms
# 76:	learn: 0.0670487	total: 40.1ms	remaining: 116ms
# 77:	learn: 0.0659221	total: 40.6ms	remaining: 116ms
# 78:	learn: 0.0647439	total: 41.1ms	remaining: 115ms
# 79:	learn: 0.0635591	total: 41.6ms	remaining: 114ms
# 80:	learn: 0.0625433	total: 42.1ms	remaining: 114ms
# 81:	learn: 0.0615204	total: 42.6ms	remaining: 113ms
# 82:	learn: 0.0605834	total: 43.1ms	remaining: 113ms
# 83:	learn: 0.0597089	total: 43.6ms	remaining: 112ms
# 84:	learn: 0.0589414	total: 44.1ms	remaining: 112ms
# 85:	learn: 0.0581162	total: 44.6ms	remaining: 111ms
# 86:	learn: 0.0574111	total: 45.2ms	remaining: 111ms
# 87:	learn: 0.0564707	total: 45.7ms	remaining: 110ms
# 88:	learn: 0.0557160	total: 46.2ms	remaining: 110ms
# 89:	learn: 0.0548490	total: 46.7ms	remaining: 109ms
# 90:	learn: 0.0540039	total: 47.2ms	remaining: 109ms
# 91:	learn: 0.0532889	total: 47.7ms	remaining: 108ms
# 92:	learn: 0.0525935	total: 48.3ms	remaining: 107ms
# 93:	learn: 0.0519732	total: 48.8ms	remaining: 107ms
# 94:	learn: 0.0513103	total: 49.3ms	remaining: 106ms
# 95:	learn: 0.0504999	total: 49.8ms	remaining: 106ms
# 96:	learn: 0.0497879	total: 50.3ms	remaining: 105ms
# 97:	learn: 0.0491662	total: 50.8ms	remaining: 105ms
# 98:	learn: 0.0484586	total: 51.3ms	remaining: 104ms
# 99:	learn: 0.0477757	total: 51.8ms	remaining: 104ms
# 100:	learn: 0.0471954	total: 52.3ms	remaining: 103ms
# 101:	learn: 0.0466152	total: 52.8ms	remaining: 103ms
# 102:	learn: 0.0458172	total: 53.4ms	remaining: 102ms
# 103:	learn: 0.0453365	total: 53.8ms	remaining: 101ms
# 104:	learn: 0.0448263	total: 54.4ms	remaining: 101ms
# 105:	learn: 0.0443114	total: 54.9ms	remaining: 100ms
# 106:	learn: 0.0439140	total: 55.4ms	remaining: 100ms
# 107:	learn: 0.0433372	total: 56ms	remaining: 99.5ms
# 108:	learn: 0.0427499	total: 56.4ms	remaining: 98.9ms
# 109:	learn: 0.0422713	total: 56.9ms	remaining: 98.4ms
# 110:	learn: 0.0418125	total: 57.5ms	remaining: 97.8ms
# 111:	learn: 0.0413847	total: 58ms	remaining: 97.3ms
# 112:	learn: 0.0410192	total: 58.5ms	remaining: 96.8ms
# 113:	learn: 0.0406060	total: 59ms	remaining: 96.2ms
# 114:	learn: 0.0401933	total: 59.5ms	remaining: 95.7ms
# 115:	learn: 0.0397952	total: 60ms	remaining: 95.1ms
# 116:	learn: 0.0394128	total: 60.5ms	remaining: 94.6ms
# 117:	learn: 0.0389083	total: 61ms	remaining: 94.1ms
# 118:	learn: 0.0384931	total: 61.5ms	remaining: 93.5ms
# 119:	learn: 0.0380943	total: 61.9ms	remaining: 92.9ms
# 120:	learn: 0.0376081	total: 62.4ms	remaining: 92.3ms
# 121:	learn: 0.0372011	total: 62.9ms	remaining: 91.8ms
# 122:	learn: 0.0368675	total: 63.4ms	remaining: 91.3ms
# 123:	learn: 0.0365298	total: 63.9ms	remaining: 90.7ms
# 124:	learn: 0.0361856	total: 64.4ms	remaining: 90.2ms
# 125:	learn: 0.0358951	total: 64.9ms	remaining: 89.6ms
# 126:	learn: 0.0355283	total: 65.4ms	remaining: 89ms
# 127:	learn: 0.0352135	total: 65.9ms	remaining: 88.5ms
# 128:	learn: 0.0349139	total: 66.3ms	remaining: 87.9ms
# 129:	learn: 0.0346258	total: 66.8ms	remaining: 87.4ms
# 130:	learn: 0.0341554	total: 67.4ms	remaining: 86.9ms
# 131:	learn: 0.0337415	total: 67.9ms	remaining: 86.4ms
# 132:	learn: 0.0334390	total: 68.4ms	remaining: 85.9ms
# 133:	learn: 0.0330911	total: 68.7ms	remaining: 85.2ms
# 134:	learn: 0.0327800	total: 69.2ms	remaining: 84.6ms
# 135:	learn: 0.0325023	total: 69.7ms	remaining: 84.1ms
# 136:	learn: 0.0321982	total: 70.2ms	remaining: 83.5ms
# 137:	learn: 0.0319271	total: 70.7ms	remaining: 83ms
# 138:	learn: 0.0316295	total: 71.2ms	remaining: 82.5ms
# 139:	learn: 0.0313593	total: 71.8ms	remaining: 82.1ms
# 140:	learn: 0.0310412	total: 72.4ms	remaining: 81.6ms
# 141:	learn: 0.0307851	total: 72.9ms	remaining: 81.2ms
# 142:	learn: 0.0305379	total: 73.5ms	remaining: 80.7ms
# 143:	learn: 0.0302989	total: 74ms	remaining: 80.1ms
# 144:	learn: 0.0300900	total: 74.5ms	remaining: 79.6ms
# 145:	learn: 0.0298681	total: 74.9ms	remaining: 79ms
# 146:	learn: 0.0295804	total: 75.5ms	remaining: 78.5ms
# 147:	learn: 0.0293179	total: 76ms	remaining: 78.1ms
# 148:	learn: 0.0291060	total: 76.5ms	remaining: 77.5ms
# 149:	learn: 0.0288651	total: 77ms	remaining: 77ms
# 150:	learn: 0.0286503	total: 77.5ms	remaining: 76.5ms
# 151:	learn: 0.0284224	total: 78ms	remaining: 75.9ms
# 152:	learn: 0.0282403	total: 78.4ms	remaining: 75.4ms
# 153:	learn: 0.0280970	total: 78.9ms	remaining: 74.8ms
# 154:	learn: 0.0278833	total: 79.4ms	remaining: 74.3ms
# 155:	learn: 0.0276565	total: 79.9ms	remaining: 73.8ms
# 156:	learn: 0.0273914	total: 80.4ms	remaining: 73.3ms
# 157:	learn: 0.0271883	total: 81ms	remaining: 72.8ms
# 158:	learn: 0.0269510	total: 81.5ms	remaining: 72.3ms
# 159:	learn: 0.0267534	total: 82ms	remaining: 71.7ms
# 160:	learn: 0.0265368	total: 82.5ms	remaining: 71.2ms
# 161:	learn: 0.0263290	total: 83ms	remaining: 70.7ms
# 162:	learn: 0.0261372	total: 83.5ms	remaining: 70.1ms
# 163:	learn: 0.0259737	total: 84ms	remaining: 69.6ms
# 164:	learn: 0.0258381	total: 84.5ms	remaining: 69.1ms
# 165:	learn: 0.0256681	total: 85ms	remaining: 68.6ms
# 166:	learn: 0.0254800	total: 85.5ms	remaining: 68.1ms
# 167:	learn: 0.0253193	total: 86ms	remaining: 67.5ms
# 168:	learn: 0.0251195	total: 86.5ms	remaining: 67ms
# 169:	learn: 0.0249380	total: 87.5ms	remaining: 66.9ms
# 170:	learn: 0.0247334	total: 88.2ms	remaining: 66.6ms
# 171:	learn: 0.0245925	total: 88.8ms	remaining: 66.1ms
# 172:	learn: 0.0244591	total: 89.3ms	remaining: 65.5ms
# 173:	learn: 0.0243252	total: 89.8ms	remaining: 65ms
# 174:	learn: 0.0241607	total: 90.2ms	remaining: 64.4ms
# 175:	learn: 0.0239821	total: 90.8ms	remaining: 64ms
# 176:	learn: 0.0237998	total: 91.3ms	remaining: 63.4ms
# 177:	learn: 0.0236569	total: 91.8ms	remaining: 62.9ms
# 178:	learn: 0.0234779	total: 92.2ms	remaining: 62.3ms
# 179:	learn: 0.0232878	total: 92.7ms	remaining: 61.8ms
# 180:	learn: 0.0230566	total: 93.2ms	remaining: 61.3ms
# 181:	learn: 0.0228884	total: 93.7ms	remaining: 60.8ms
# 182:	learn: 0.0227343	total: 94.2ms	remaining: 60.2ms
# 183:	learn: 0.0225333	total: 94.8ms	remaining: 59.8ms
# 184:	learn: 0.0224089	total: 95.4ms	remaining: 59.3ms
# 185:	learn: 0.0223110	total: 95.8ms	remaining: 58.7ms
# 186:	learn: 0.0221601	total: 96.3ms	remaining: 58.2ms
# 187:	learn: 0.0220519	total: 96.8ms	remaining: 57.7ms
# 188:	learn: 0.0219071	total: 97.3ms	remaining: 57.1ms
# 189:	learn: 0.0217858	total: 97.8ms	remaining: 56.6ms
# 190:	learn: 0.0216676	total: 98.3ms	remaining: 56.1ms
# 191:	learn: 0.0215677	total: 98.9ms	remaining: 55.6ms
# 192:	learn: 0.0214531	total: 99.2ms	remaining: 55ms
# 193:	learn: 0.0213421	total: 99.9ms	remaining: 54.6ms
# 194:	learn: 0.0212117	total: 100ms	remaining: 54.1ms
# 195:	learn: 0.0211225	total: 101ms	remaining: 53.6ms
# 196:	learn: 0.0209875	total: 102ms	remaining: 53.1ms
# 197:	learn: 0.0208800	total: 102ms	remaining: 52.5ms
# 198:	learn: 0.0207660	total: 102ms	remaining: 52ms
# 199:	learn: 0.0206298	total: 103ms	remaining: 51.5ms
# 200:	learn: 0.0204796	total: 103ms	remaining: 50.9ms
# 201:	learn: 0.0203534	total: 106ms	remaining: 51.3ms
# 202:	learn: 0.0202253	total: 109ms	remaining: 52ms
# 203:	learn: 0.0200628	total: 110ms	remaining: 51.5ms
# 204:	learn: 0.0199266	total: 111ms	remaining: 51.3ms
# 205:	learn: 0.0198206	total: 112ms	remaining: 51.2ms
# 206:	learn: 0.0196729	total: 114ms	remaining: 51.3ms
# 207:	learn: 0.0195714	total: 115ms	remaining: 51.1ms
# 208:	learn: 0.0194680	total: 116ms	remaining: 50.7ms
# 209:	learn: 0.0193407	total: 117ms	remaining: 50.3ms
# 210:	learn: 0.0192693	total: 118ms	remaining: 49.7ms
# 211:	learn: 0.0191464	total: 118ms	remaining: 49.1ms
# 212:	learn: 0.0190579	total: 119ms	remaining: 48.5ms
# 213:	learn: 0.0189557	total: 119ms	remaining: 48ms
# 214:	learn: 0.0188384	total: 120ms	remaining: 47.4ms
# 215:	learn: 0.0187531	total: 120ms	remaining: 46.8ms
# 216:	learn: 0.0186318	total: 121ms	remaining: 46.2ms
# 217:	learn: 0.0185448	total: 121ms	remaining: 45.6ms
# 218:	learn: 0.0184407	total: 122ms	remaining: 45.1ms
# 219:	learn: 0.0183492	total: 122ms	remaining: 44.5ms
# 220:	learn: 0.0182681	total: 123ms	remaining: 43.9ms
# 221:	learn: 0.0181683	total: 124ms	remaining: 43.6ms
# 222:	learn: 0.0180822	total: 125ms	remaining: 43.1ms
# 223:	learn: 0.0180011	total: 126ms	remaining: 42.6ms
# 224:	learn: 0.0179175	total: 126ms	remaining: 42.1ms
# 225:	learn: 0.0178284	total: 127ms	remaining: 41.5ms
# 226:	learn: 0.0177459	total: 127ms	remaining: 40.9ms
# 227:	learn: 0.0176054	total: 128ms	remaining: 40.3ms
# 228:	learn: 0.0174767	total: 128ms	remaining: 39.8ms
# 229:	learn: 0.0174011	total: 129ms	remaining: 39.2ms
# 230:	learn: 0.0173379	total: 129ms	remaining: 38.6ms
# 231:	learn: 0.0171993	total: 130ms	remaining: 38.1ms
# 232:	learn: 0.0170971	total: 130ms	remaining: 37.5ms
# 233:	learn: 0.0170111	total: 131ms	remaining: 36.9ms
# 234:	learn: 0.0168972	total: 131ms	remaining: 36.4ms
# 235:	learn: 0.0168028	total: 132ms	remaining: 35.8ms
# 236:	learn: 0.0167286	total: 133ms	remaining: 35.2ms
# 237:	learn: 0.0166312	total: 133ms	remaining: 34.7ms
# 238:	learn: 0.0165544	total: 134ms	remaining: 34.2ms
# 239:	learn: 0.0164725	total: 135ms	remaining: 33.7ms
# 240:	learn: 0.0163857	total: 135ms	remaining: 33.1ms
# 241:	learn: 0.0163180	total: 136ms	remaining: 32.5ms
# 242:	learn: 0.0162495	total: 136ms	remaining: 32ms
# 243:	learn: 0.0161746	total: 137ms	remaining: 31.4ms
# 244:	learn: 0.0161191	total: 137ms	remaining: 30.8ms
# 245:	learn: 0.0160190	total: 138ms	remaining: 30.3ms
# 246:	learn: 0.0159526	total: 138ms	remaining: 29.7ms
# 247:	learn: 0.0158819	total: 139ms	remaining: 29.1ms
# 248:	learn: 0.0157936	total: 139ms	remaining: 28.6ms
# 249:	learn: 0.0157114	total: 140ms	remaining: 28ms
# 250:	learn: 0.0156002	total: 140ms	remaining: 27.4ms
# 251:	learn: 0.0155458	total: 141ms	remaining: 26.8ms
# 252:	learn: 0.0154609	total: 141ms	remaining: 26.3ms
# 253:	learn: 0.0153987	total: 142ms	remaining: 25.7ms
# 254:	learn: 0.0153030	total: 142ms	remaining: 25.1ms
# 255:	learn: 0.0152077	total: 143ms	remaining: 24.6ms
# 256:	learn: 0.0151495	total: 143ms	remaining: 24ms
# 257:	learn: 0.0150966	total: 144ms	remaining: 23.4ms
# 258:	learn: 0.0150321	total: 144ms	remaining: 22.9ms
# 259:	learn: 0.0149469	total: 145ms	remaining: 22.3ms
# 260:	learn: 0.0148710	total: 145ms	remaining: 21.7ms
# 261:	learn: 0.0148010	total: 146ms	remaining: 21.2ms
# 262:	learn: 0.0147432	total: 146ms	remaining: 20.6ms
# 263:	learn: 0.0146742	total: 147ms	remaining: 20ms
# 264:	learn: 0.0146204	total: 147ms	remaining: 19.5ms
# 265:	learn: 0.0145711	total: 148ms	remaining: 18.9ms
# 266:	learn: 0.0145066	total: 148ms	remaining: 18.4ms
# 267:	learn: 0.0144158	total: 149ms	remaining: 17.8ms
# 268:	learn: 0.0143640	total: 150ms	remaining: 17.2ms
# 269:	learn: 0.0143009	total: 150ms	remaining: 16.7ms
# 270:	learn: 0.0142334	total: 151ms	remaining: 16.1ms
# 271:	learn: 0.0141739	total: 151ms	remaining: 15.5ms
# 272:	learn: 0.0141199	total: 152ms	remaining: 15ms
# 273:	learn: 0.0140592	total: 152ms	remaining: 14.4ms
# 274:	learn: 0.0139702	total: 153ms	remaining: 13.9ms
# 275:	learn: 0.0139128	total: 153ms	remaining: 13.3ms
# 276:	learn: 0.0138682	total: 154ms	remaining: 12.8ms
# 277:	learn: 0.0138107	total: 154ms	remaining: 12.2ms
# 278:	learn: 0.0137710	total: 155ms	remaining: 11.6ms
# 279:	learn: 0.0137136	total: 155ms	remaining: 11.1ms
# 280:	learn: 0.0136632	total: 156ms	remaining: 10.5ms
# 281:	learn: 0.0135935	total: 156ms	remaining: 9.96ms
# 282:	learn: 0.0135343	total: 157ms	remaining: 9.41ms
# 283:	learn: 0.0134860	total: 157ms	remaining: 8.85ms
# 284:	learn: 0.0134454	total: 158ms	remaining: 8.29ms
# 285:	learn: 0.0134021	total: 158ms	remaining: 7.74ms
# 286:	learn: 0.0133534	total: 159ms	remaining: 7.18ms
# 287:	learn: 0.0133102	total: 159ms	remaining: 6.63ms
# 288:	learn: 0.0132626	total: 160ms	remaining: 6.07ms
# 289:	learn: 0.0132132	total: 160ms	remaining: 5.52ms
# 290:	learn: 0.0131518	total: 160ms	remaining: 4.96ms
# 291:	learn: 0.0131029	total: 161ms	remaining: 4.41ms
# 292:	learn: 0.0130522	total: 161ms	remaining: 3.85ms
# 293:	learn: 0.0129983	total: 162ms	remaining: 3.3ms
# 294:	learn: 0.0129432	total: 162ms	remaining: 2.75ms
# 295:	learn: 0.0129081	total: 163ms	remaining: 2.2ms
# 296:	learn: 0.0128656	total: 163ms	remaining: 1.65ms
# 297:	learn: 0.0128025	total: 164ms	remaining: 1.1ms
# 298:	learn: 0.0127628	total: 164ms	remaining: 549us
# 299:	learn: 0.0127227	total: 165ms	remaining: 0us
# 0:	learn: 0.9714655	total: 487us	remaining: 146ms
# 1:	learn: 0.8813433	total: 882us	remaining: 131ms
# 2:	learn: 0.8015632	total: 1.3ms	remaining: 128ms
# 3:	learn: 0.7281756	total: 2.45ms	remaining: 182ms
# 4:	learn: 0.6614262	total: 3.09ms	remaining: 183ms
# 5:	learn: 0.6058588	total: 3.71ms	remaining: 182ms
# 6:	learn: 0.5611935	total: 4.26ms	remaining: 179ms
# 7:	learn: 0.5151372	total: 4.85ms	remaining: 177ms
# 8:	learn: 0.4780156	total: 5.18ms	remaining: 168ms
# 9:	learn: 0.4439700	total: 5.66ms	remaining: 164ms
# 10:	learn: 0.4145577	total: 6.28ms	remaining: 165ms
# 11:	learn: 0.3885865	total: 6.96ms	remaining: 167ms
# 12:	learn: 0.3642442	total: 7.42ms	remaining: 164ms
# 13:	learn: 0.3463592	total: 8ms	remaining: 163ms
# 14:	learn: 0.3256988	total: 9.04ms	remaining: 172ms
# 15:	learn: 0.3065281	total: 9.63ms	remaining: 171ms
# 16:	learn: 0.2889097	total: 10.7ms	remaining: 178ms
# 17:	learn: 0.2761055	total: 11.2ms	remaining: 176ms
# 18:	learn: 0.2590339	total: 11.9ms	remaining: 177ms
# 19:	learn: 0.2450549	total: 12.8ms	remaining: 179ms
# 20:	learn: 0.2355592	total: 13.7ms	remaining: 182ms
# 21:	learn: 0.2241447	total: 14.3ms	remaining: 181ms
# 22:	learn: 0.2111816	total: 14.9ms	remaining: 180ms
# 23:	learn: 0.2010696	total: 15.6ms	remaining: 179ms
# 24:	learn: 0.1928143	total: 16.2ms	remaining: 179ms
# 25:	learn: 0.1846649	total: 16.8ms	remaining: 177ms
# 26:	learn: 0.1772749	total: 17.4ms	remaining: 176ms
# 27:	learn: 0.1688139	total: 17.9ms	remaining: 174ms
# 28:	learn: 0.1621639	total: 18.4ms	remaining: 172ms
# 29:	learn: 0.1536147	total: 19ms	remaining: 171ms
# 30:	learn: 0.1485337	total: 19.4ms	remaining: 168ms
# 31:	learn: 0.1439130	total: 19.9ms	remaining: 167ms
# 32:	learn: 0.1384252	total: 20.5ms	remaining: 166ms
# 33:	learn: 0.1340413	total: 21ms	remaining: 164ms
# 34:	learn: 0.1310592	total: 21.5ms	remaining: 163ms
# 35:	learn: 0.1265359	total: 22ms	remaining: 161ms
# 36:	learn: 0.1215771	total: 22.5ms	remaining: 160ms
# 37:	learn: 0.1180981	total: 22.9ms	remaining: 158ms
# 38:	learn: 0.1141790	total: 23.4ms	remaining: 157ms
# 39:	learn: 0.1094028	total: 23.9ms	remaining: 156ms
# 40:	learn: 0.1064618	total: 24.6ms	remaining: 156ms
# 41:	learn: 0.1031924	total: 25.1ms	remaining: 154ms
# 42:	learn: 0.1002106	total: 25.6ms	remaining: 153ms
# 43:	learn: 0.0976466	total: 26.1ms	remaining: 152ms
# 44:	learn: 0.0943255	total: 26.7ms	remaining: 151ms
# 45:	learn: 0.0911292	total: 27.2ms	remaining: 150ms
# 46:	learn: 0.0885657	total: 27.9ms	remaining: 150ms
# 47:	learn: 0.0865208	total: 28.8ms	remaining: 151ms
# 48:	learn: 0.0848862	total: 29.5ms	remaining: 151ms
# 49:	learn: 0.0829885	total: 30ms	remaining: 150ms
# 50:	learn: 0.0811591	total: 30.6ms	remaining: 149ms
# 51:	learn: 0.0793106	total: 31.1ms	remaining: 148ms
# 52:	learn: 0.0767338	total: 31.6ms	remaining: 147ms
# 53:	learn: 0.0749592	total: 32.2ms	remaining: 147ms
# 54:	learn: 0.0727995	total: 32.7ms	remaining: 146ms
# 55:	learn: 0.0710514	total: 33.2ms	remaining: 145ms
# 56:	learn: 0.0697607	total: 33.8ms	remaining: 144ms
# 57:	learn: 0.0681679	total: 34.3ms	remaining: 143ms
# 58:	learn: 0.0657239	total: 34.8ms	remaining: 142ms
# 59:	learn: 0.0638974	total: 35.3ms	remaining: 141ms
# 60:	learn: 0.0622971	total: 35.8ms	remaining: 140ms
# 61:	learn: 0.0610674	total: 36.4ms	remaining: 140ms
# 62:	learn: 0.0592051	total: 37ms	remaining: 139ms
# 63:	learn: 0.0574993	total: 37.6ms	remaining: 139ms
# 64:	learn: 0.0560511	total: 38.1ms	remaining: 138ms
# 65:	learn: 0.0546194	total: 38.7ms	remaining: 137ms
# 66:	learn: 0.0534354	total: 39.2ms	remaining: 136ms
# 67:	learn: 0.0524993	total: 39.7ms	remaining: 136ms
# 68:	learn: 0.0514169	total: 40.3ms	remaining: 135ms
# 69:	learn: 0.0503480	total: 40.9ms	remaining: 134ms
# 70:	learn: 0.0493119	total: 41.2ms	remaining: 133ms
# 71:	learn: 0.0482821	total: 41.8ms	remaining: 132ms
# 72:	learn: 0.0475303	total: 42.3ms	remaining: 132ms
# 73:	learn: 0.0467507	total: 42.8ms	remaining: 131ms
# 74:	learn: 0.0458177	total: 43.3ms	remaining: 130ms
# 75:	learn: 0.0448631	total: 43.9ms	remaining: 129ms
# 76:	learn: 0.0440009	total: 44.4ms	remaining: 129ms
# 77:	learn: 0.0434467	total: 44.9ms	remaining: 128ms
# 78:	learn: 0.0426020	total: 45.4ms	remaining: 127ms
# 79:	learn: 0.0418411	total: 45.9ms	remaining: 126ms
# 80:	learn: 0.0411594	total: 46.5ms	remaining: 126ms
# 81:	learn: 0.0406086	total: 47ms	remaining: 125ms
# 82:	learn: 0.0399628	total: 47.5ms	remaining: 124ms
# 83:	learn: 0.0392571	total: 48ms	remaining: 123ms
# 84:	learn: 0.0386240	total: 48.5ms	remaining: 123ms
# 85:	learn: 0.0379360	total: 49.1ms	remaining: 122ms
# 86:	learn: 0.0374841	total: 49.8ms	remaining: 122ms
# 87:	learn: 0.0370073	total: 50.3ms	remaining: 121ms
# 88:	learn: 0.0364966	total: 50.8ms	remaining: 120ms
# 89:	learn: 0.0358323	total: 51.3ms	remaining: 120ms
# 90:	learn: 0.0351747	total: 51.9ms	remaining: 119ms
# 91:	learn: 0.0347403	total: 52.5ms	remaining: 119ms
# 92:	learn: 0.0343559	total: 53ms	remaining: 118ms
# 93:	learn: 0.0340051	total: 53.5ms	remaining: 117ms
# 94:	learn: 0.0334932	total: 54ms	remaining: 117ms
# 95:	learn: 0.0331170	total: 54.6ms	remaining: 116ms
# 96:	learn: 0.0326661	total: 55.1ms	remaining: 115ms
# 97:	learn: 0.0323685	total: 55.6ms	remaining: 115ms
# 98:	learn: 0.0318651	total: 56.1ms	remaining: 114ms
# 99:	learn: 0.0315478	total: 56.6ms	remaining: 113ms
# 100:	learn: 0.0312727	total: 57.2ms	remaining: 113ms
# 101:	learn: 0.0308490	total: 57.7ms	remaining: 112ms
# 102:	learn: 0.0303413	total: 58.2ms	remaining: 111ms
# 103:	learn: 0.0300076	total: 58.7ms	remaining: 111ms
# 104:	learn: 0.0297111	total: 59.2ms	remaining: 110ms
# 105:	learn: 0.0293990	total: 59.7ms	remaining: 109ms
# 106:	learn: 0.0290655	total: 60.2ms	remaining: 109ms
# 107:	learn: 0.0286936	total: 60.7ms	remaining: 108ms
# 108:	learn: 0.0284236	total: 61.2ms	remaining: 107ms
# 109:	learn: 0.0281693	total: 61.7ms	remaining: 107ms
# 110:	learn: 0.0278223	total: 62.3ms	remaining: 106ms
# 111:	learn: 0.0275332	total: 62.8ms	remaining: 105ms
# 112:	learn: 0.0272947	total: 63.3ms	remaining: 105ms
# 113:	learn: 0.0269852	total: 63.8ms	remaining: 104ms
# 114:	learn: 0.0267143	total: 64.3ms	remaining: 103ms
# 115:	learn: 0.0264219	total: 64.8ms	remaining: 103ms
# 116:	learn: 0.0260375	total: 65.3ms	remaining: 102ms
# 117:	learn: 0.0257657	total: 65.9ms	remaining: 102ms
# 118:	learn: 0.0255266	total: 66.4ms	remaining: 101ms
# 119:	learn: 0.0251614	total: 66.9ms	remaining: 100ms
# 120:	learn: 0.0249103	total: 67.9ms	remaining: 101ms
# 121:	learn: 0.0247092	total: 68.7ms	remaining: 100ms
# 122:	learn: 0.0244795	total: 69.3ms	remaining: 99.8ms
# 123:	learn: 0.0241596	total: 69.9ms	remaining: 99.2ms
# 124:	learn: 0.0239803	total: 70.5ms	remaining: 98.7ms
# 125:	learn: 0.0236561	total: 71.1ms	remaining: 98.1ms
# 126:	learn: 0.0234538	total: 71.6ms	remaining: 97.6ms
# 127:	learn: 0.0232293	total: 72.2ms	remaining: 97ms
# 128:	learn: 0.0230543	total: 73ms	remaining: 96.7ms
# 129:	learn: 0.0227527	total: 73.6ms	remaining: 96.2ms
# 130:	learn: 0.0224706	total: 73.9ms	remaining: 95.4ms
# 131:	learn: 0.0222799	total: 74.6ms	remaining: 95ms
# 132:	learn: 0.0220413	total: 75.2ms	remaining: 94.4ms
# 133:	learn: 0.0218579	total: 75.9ms	remaining: 94ms
# 134:	learn: 0.0216498	total: 76.7ms	remaining: 93.8ms
# 135:	learn: 0.0214105	total: 77.6ms	remaining: 93.6ms
# 136:	learn: 0.0212499	total: 78.5ms	remaining: 93.3ms
# 137:	learn: 0.0210991	total: 79ms	remaining: 92.7ms
# 138:	learn: 0.0208405	total: 79.3ms	remaining: 91.9ms
# 139:	learn: 0.0206791	total: 79.6ms	remaining: 91ms
# 140:	learn: 0.0204279	total: 80.5ms	remaining: 90.8ms
# 141:	learn: 0.0202198	total: 81ms	remaining: 90.2ms
# 142:	learn: 0.0200670	total: 81.6ms	remaining: 89.6ms
# 143:	learn: 0.0199045	total: 82.5ms	remaining: 89.4ms
# 144:	learn: 0.0197675	total: 83.4ms	remaining: 89.1ms
# 145:	learn: 0.0196546	total: 84.3ms	remaining: 88.9ms
# 146:	learn: 0.0195067	total: 85.2ms	remaining: 88.7ms
# 147:	learn: 0.0193494	total: 86ms	remaining: 88.3ms
# 148:	learn: 0.0192376	total: 86.7ms	remaining: 87.8ms
# 149:	learn: 0.0191205	total: 87.5ms	remaining: 87.5ms
# 150:	learn: 0.0189796	total: 88.1ms	remaining: 86.9ms
# 151:	learn: 0.0188661	total: 88.6ms	remaining: 86.3ms
# 152:	learn: 0.0187100	total: 89.1ms	remaining: 85.6ms
# 153:	learn: 0.0185478	total: 89.7ms	remaining: 85ms
# 154:	learn: 0.0184268	total: 90.2ms	remaining: 84.4ms
# 155:	learn: 0.0182644	total: 90.7ms	remaining: 83.7ms
# 156:	learn: 0.0181324	total: 91.2ms	remaining: 83.1ms
# 157:	learn: 0.0179711	total: 91.7ms	remaining: 82.4ms
# 158:	learn: 0.0178689	total: 92.2ms	remaining: 81.8ms
# 159:	learn: 0.0177583	total: 92.7ms	remaining: 81.1ms
# 160:	learn: 0.0176779	total: 93.2ms	remaining: 80.5ms
# 161:	learn: 0.0175206	total: 93.7ms	remaining: 79.8ms
# 162:	learn: 0.0174100	total: 94.2ms	remaining: 79.2ms
# 163:	learn: 0.0172910	total: 94.7ms	remaining: 78.5ms
# 164:	learn: 0.0171536	total: 95.2ms	remaining: 77.9ms
# 165:	learn: 0.0170532	total: 95.7ms	remaining: 77.3ms
# 166:	learn: 0.0168931	total: 96.2ms	remaining: 76.6ms
# 167:	learn: 0.0167861	total: 96.7ms	remaining: 76ms
# 168:	learn: 0.0166867	total: 97.2ms	remaining: 75.3ms
# 169:	learn: 0.0166033	total: 97.7ms	remaining: 74.7ms
# 170:	learn: 0.0164744	total: 98.2ms	remaining: 74.1ms
# 171:	learn: 0.0163790	total: 98.7ms	remaining: 73.4ms
# 172:	learn: 0.0162654	total: 99.2ms	remaining: 72.8ms
# 173:	learn: 0.0161355	total: 99.7ms	remaining: 72.2ms
# 174:	learn: 0.0160271	total: 100ms	remaining: 71.6ms
# 175:	learn: 0.0159068	total: 101ms	remaining: 70.9ms
# 176:	learn: 0.0157854	total: 101ms	remaining: 70.3ms
# 177:	learn: 0.0157076	total: 102ms	remaining: 69.7ms
# 178:	learn: 0.0155664	total: 102ms	remaining: 69.1ms
# 179:	learn: 0.0154842	total: 103ms	remaining: 68.5ms
# 180:	learn: 0.0153666	total: 103ms	remaining: 67.8ms
# 181:	learn: 0.0152397	total: 104ms	remaining: 67.2ms
# 182:	learn: 0.0151266	total: 104ms	remaining: 66.6ms
# 183:	learn: 0.0149901	total: 105ms	remaining: 66ms
# 184:	learn: 0.0148841	total: 105ms	remaining: 65.3ms
# 185:	learn: 0.0147978	total: 106ms	remaining: 64.7ms
# 186:	learn: 0.0146880	total: 106ms	remaining: 64.1ms
# 187:	learn: 0.0146277	total: 107ms	remaining: 63.5ms
# 188:	learn: 0.0145174	total: 107ms	remaining: 63ms
# 189:	learn: 0.0144367	total: 108ms	remaining: 62.3ms
# 190:	learn: 0.0143573	total: 108ms	remaining: 61.7ms
# 191:	learn: 0.0142612	total: 109ms	remaining: 61.1ms
# 192:	learn: 0.0141794	total: 109ms	remaining: 60.5ms
# 193:	learn: 0.0140771	total: 110ms	remaining: 59.9ms
# 194:	learn: 0.0140049	total: 110ms	remaining: 59.3ms
# 195:	learn: 0.0138974	total: 111ms	remaining: 58.7ms
# 196:	learn: 0.0138059	total: 111ms	remaining: 58.1ms
# 197:	learn: 0.0137074	total: 112ms	remaining: 57.6ms
# 198:	learn: 0.0136348	total: 112ms	remaining: 57ms
# 199:	learn: 0.0135256	total: 113ms	remaining: 56.4ms
# 200:	learn: 0.0134666	total: 113ms	remaining: 55.8ms
# 201:	learn: 0.0133796	total: 114ms	remaining: 55.3ms
# 202:	learn: 0.0132849	total: 114ms	remaining: 54.7ms
# 203:	learn: 0.0131918	total: 115ms	remaining: 54ms
# 204:	learn: 0.0131085	total: 115ms	remaining: 53.5ms
# 205:	learn: 0.0130561	total: 116ms	remaining: 52.9ms
# 206:	learn: 0.0129636	total: 117ms	remaining: 52.4ms
# 207:	learn: 0.0128595	total: 117ms	remaining: 51.8ms
# 208:	learn: 0.0127583	total: 118ms	remaining: 51.2ms
# 209:	learn: 0.0126953	total: 118ms	remaining: 50.6ms
# 210:	learn: 0.0126217	total: 119ms	remaining: 50.3ms
# 211:	learn: 0.0125544	total: 120ms	remaining: 50ms
# 212:	learn: 0.0124671	total: 121ms	remaining: 49.5ms
# 213:	learn: 0.0123928	total: 122ms	remaining: 49ms
# 214:	learn: 0.0123336	total: 123ms	remaining: 48.5ms
# 215:	learn: 0.0122586	total: 123ms	remaining: 48ms
# 216:	learn: 0.0121984	total: 124ms	remaining: 47.5ms
# 217:	learn: 0.0121106	total: 125ms	remaining: 46.9ms
# 218:	learn: 0.0120315	total: 125ms	remaining: 46.4ms
# 219:	learn: 0.0119806	total: 126ms	remaining: 45.8ms
# 220:	learn: 0.0119371	total: 127ms	remaining: 45.3ms
# 221:	learn: 0.0118894	total: 127ms	remaining: 44.7ms
# 222:	learn: 0.0118263	total: 128ms	remaining: 44.2ms
# 223:	learn: 0.0117499	total: 129ms	remaining: 43.7ms
# 224:	learn: 0.0116883	total: 130ms	remaining: 43.2ms
# 225:	learn: 0.0116235	total: 130ms	remaining: 42.6ms
# 226:	learn: 0.0115416	total: 131ms	remaining: 42ms
# 227:	learn: 0.0114851	total: 131ms	remaining: 41.4ms
# 228:	learn: 0.0114339	total: 132ms	remaining: 40.8ms
# 229:	learn: 0.0113659	total: 132ms	remaining: 40.2ms
# 230:	learn: 0.0113199	total: 133ms	remaining: 39.6ms
# 231:	learn: 0.0112769	total: 133ms	remaining: 39ms
# 232:	learn: 0.0111972	total: 134ms	remaining: 38.4ms
# 233:	learn: 0.0111352	total: 134ms	remaining: 37.8ms
# 234:	learn: 0.0110711	total: 134ms	remaining: 37.2ms
# 235:	learn: 0.0109963	total: 135ms	remaining: 36.6ms
# 236:	learn: 0.0109613	total: 136ms	remaining: 36ms
# 237:	learn: 0.0108991	total: 136ms	remaining: 35.4ms
# 238:	learn: 0.0108503	total: 137ms	remaining: 34.9ms
# 239:	learn: 0.0108103	total: 137ms	remaining: 34.3ms
# 240:	learn: 0.0107540	total: 138ms	remaining: 33.7ms
# 241:	learn: 0.0107201	total: 138ms	remaining: 33.1ms
# 242:	learn: 0.0106841	total: 138ms	remaining: 32.5ms
# 243:	learn: 0.0106246	total: 139ms	remaining: 31.9ms
# 244:	learn: 0.0105703	total: 140ms	remaining: 31.4ms
# 245:	learn: 0.0105261	total: 140ms	remaining: 30.8ms
# 246:	learn: 0.0104562	total: 141ms	remaining: 30.2ms
# 247:	learn: 0.0104240	total: 141ms	remaining: 29.6ms
# 248:	learn: 0.0103654	total: 142ms	remaining: 29.1ms
# 249:	learn: 0.0103087	total: 142ms	remaining: 28.5ms
# 250:	learn: 0.0102716	total: 143ms	remaining: 27.9ms
# 251:	learn: 0.0102333	total: 143ms	remaining: 27.3ms
# 252:	learn: 0.0101929	total: 144ms	remaining: 26.7ms
# 253:	learn: 0.0101429	total: 144ms	remaining: 26.1ms
# 254:	learn: 0.0100988	total: 145ms	remaining: 25.6ms
# 255:	learn: 0.0100479	total: 145ms	remaining: 25ms
# 256:	learn: 0.0100030	total: 146ms	remaining: 24.4ms
# 257:	learn: 0.0099530	total: 146ms	remaining: 23.8ms
# 258:	learn: 0.0099085	total: 147ms	remaining: 23.3ms
# 259:	learn: 0.0098606	total: 147ms	remaining: 22.7ms
# 260:	learn: 0.0098223	total: 148ms	remaining: 22.1ms
# 261:	learn: 0.0097782	total: 148ms	remaining: 21.5ms
# 262:	learn: 0.0097252	total: 149ms	remaining: 21ms
# 263:	learn: 0.0096801	total: 149ms	remaining: 20.4ms
# 264:	learn: 0.0096354	total: 150ms	remaining: 19.8ms
# 265:	learn: 0.0096088	total: 151ms	remaining: 19.3ms
# 266:	learn: 0.0095644	total: 153ms	remaining: 18.9ms
# 267:	learn: 0.0095310	total: 153ms	remaining: 18.3ms
# 268:	learn: 0.0094946	total: 154ms	remaining: 17.7ms
# 269:	learn: 0.0094474	total: 154ms	remaining: 17.1ms
# 270:	learn: 0.0094189	total: 155ms	remaining: 16.6ms
# 271:	learn: 0.0093969	total: 155ms	remaining: 16ms
# 272:	learn: 0.0093507	total: 156ms	remaining: 15.4ms
# 273:	learn: 0.0093074	total: 156ms	remaining: 14.8ms
# 274:	learn: 0.0092686	total: 157ms	remaining: 14.2ms
# 275:	learn: 0.0092377	total: 157ms	remaining: 13.7ms
# 276:	learn: 0.0091931	total: 158ms	remaining: 13.1ms
# 277:	learn: 0.0091702	total: 158ms	remaining: 12.5ms
# 278:	learn: 0.0091440	total: 159ms	remaining: 11.9ms
# 279:	learn: 0.0091106	total: 159ms	remaining: 11.4ms
# 280:	learn: 0.0090575	total: 160ms	remaining: 10.8ms
# 281:	learn: 0.0090212	total: 160ms	remaining: 10.2ms
# 282:	learn: 0.0089910	total: 161ms	remaining: 9.65ms
# 283:	learn: 0.0089623	total: 161ms	remaining: 9.08ms
# 284:	learn: 0.0089295	total: 162ms	remaining: 8.51ms
# 285:	learn: 0.0089041	total: 162ms	remaining: 7.94ms
# 286:	learn: 0.0088730	total: 163ms	remaining: 7.37ms
# 287:	learn: 0.0088445	total: 163ms	remaining: 6.8ms
# 288:	learn: 0.0088174	total: 164ms	remaining: 6.23ms
# 289:	learn: 0.0087843	total: 164ms	remaining: 5.65ms
# 290:	learn: 0.0087575	total: 164ms	remaining: 5.09ms
# 291:	learn: 0.0087230	total: 165ms	remaining: 4.52ms
# 292:	learn: 0.0086744	total: 165ms	remaining: 3.95ms
# 293:	learn: 0.0086501	total: 166ms	remaining: 3.39ms
# 294:	learn: 0.0086132	total: 167ms	remaining: 2.82ms
# 295:	learn: 0.0085782	total: 167ms	remaining: 2.26ms
# 296:	learn: 0.0085397	total: 168ms	remaining: 1.69ms
# 297:	learn: 0.0085163	total: 168ms	remaining: 1.13ms
# 298:	learn: 0.0084720	total: 168ms	remaining: 563us
# 299:	learn: 0.0084499	total: 169ms	remaining: 0us
# 0:	learn: 0.9804962	total: 549us	remaining: 164ms
# 1:	learn: 0.8802924	total: 1.54ms	remaining: 230ms
# 2:	learn: 0.8093942	total: 2.15ms	remaining: 213ms
# 3:	learn: 0.7325562	total: 2.69ms	remaining: 199ms
# 4:	learn: 0.6697441	total: 3.21ms	remaining: 189ms
# 5:	learn: 0.6106839	total: 3.75ms	remaining: 184ms
# 6:	learn: 0.5695409	total: 4.07ms	remaining: 170ms
# 7:	learn: 0.5292261	total: 4.59ms	remaining: 168ms
# 8:	learn: 0.4885285	total: 5.08ms	remaining: 164ms
# 9:	learn: 0.4576801	total: 5.6ms	remaining: 162ms
# 10:	learn: 0.4268592	total: 6.12ms	remaining: 161ms
# ...
# 297:	learn: 0.0112215	total: 159ms	remaining: 1.07ms
# 298:	learn: 0.0111571	total: 160ms	remaining: 533us
# 299:	learn: 0.0110975	total: 160ms	remaining: 0us
# 0:	learn: 0.9765564	total: 467us	remaining: 140ms
# 1:	learn: 0.8850424	total: 1.44ms	remaining: 215ms
# 2:	learn: 0.8146349	total: 3.02ms	remaining: 299ms
# 3:	learn: 0.7390929	total: 3.37ms	remaining: 249ms
# 4:	learn: 0.6810396	total: 3.95ms	remaining: 233ms
# 5:	learn: 0.6221243	total: 4.57ms	remaining: 224ms
# 6:	learn: 0.5831970	total: 4.7ms	remaining: 197ms
# 7:	learn: 0.5389985	total: 5.22ms	remaining: 191ms
# 8:	learn: 0.5021324	total: 5.72ms	remaining: 185ms
# 9:	learn: 0.4716007	total: 6.04ms	remaining: 175ms
# 10:	learn: 0.4377455	total: 6.75ms	remaining: 177ms
# 11:	learn: 0.4135243	total: 7.31ms	remaining: 175ms
# 12:	learn: 0.3876174	total: 7.83ms	remaining: 173ms
# 13:	learn: 0.3644231	total: 8.38ms	remaining: 171ms
# 14:	learn: 0.3439030	total: 8.9ms	remaining: 169ms
# 15:	learn: 0.3243372	total: 9.41ms	remaining: 167ms
# 16:	learn: 0.3079180	total: 9.91ms	remaining: 165ms
# 17:	learn: 0.2935314	total: 10.4ms	remaining: 163ms
# 18:	learn: 0.2820399	total: 11ms	remaining: 162ms
# 19:	learn: 0.2717568	total: 11.4ms	remaining: 160ms
# 20:	learn: 0.2595826	total: 12ms	remaining: 159ms
# 21:	learn: 0.2497641	total: 12.5ms	remaining: 158ms
# 22:	learn: 0.2368849	total: 13ms	remaining: 156ms
# 23:	learn: 0.2277270	total: 13.5ms	remaining: 155ms
# 24:	learn: 0.2200614	total: 14.1ms	remaining: 155ms
# 25:	learn: 0.2129990	total: 14.7ms	remaining: 155ms
# 26:	learn: 0.2039238	total: 15.1ms	remaining: 153ms
# 27:	learn: 0.1973470	total: 15.5ms	remaining: 150ms
# 28:	learn: 0.1893425	total: 16ms	remaining: 149ms
# 29:	learn: 0.1818245	total: 16.6ms	remaining: 150ms
# 30:	learn: 0.1764275	total: 17.3ms	remaining: 150ms
# 31:	learn: 0.1717111	total: 17.9ms	remaining: 150ms
# 32:	learn: 0.1665575	total: 18.3ms	remaining: 148ms
# 33:	learn: 0.1612339	total: 18.6ms	remaining: 146ms
# 34:	learn: 0.1551356	total: 19.1ms	remaining: 145ms
# 35:	learn: 0.1499388	total: 19.6ms	remaining: 144ms
# 36:	learn: 0.1445830	total: 20.1ms	remaining: 143ms
# 37:	learn: 0.1388379	total: 21ms	remaining: 145ms
# 38:	learn: 0.1354316	total: 21.9ms	remaining: 147ms
# 39:	learn: 0.1320016	total: 22.6ms	remaining: 147ms
# 40:	learn: 0.1289625	total: 23.2ms	remaining: 146ms
# 41:	learn: 0.1251779	total: 23.7ms	remaining: 146ms
# 42:	learn: 0.1218589	total: 24.3ms	remaining: 145ms
# 43:	learn: 0.1191908	total: 24.8ms	remaining: 144ms
# 44:	learn: 0.1152575	total: 25.3ms	remaining: 143ms
# 45:	learn: 0.1126375	total: 25.8ms	remaining: 143ms
# 46:	learn: 0.1105132	total: 26.4ms	remaining: 142ms
# 47:	learn: 0.1077948	total: 26.9ms	remaining: 141ms
# 48:	learn: 0.1055937	total: 27.4ms	remaining: 140ms
# 49:	learn: 0.1025898	total: 27.9ms	remaining: 140ms
# 50:	learn: 0.0996824	total: 28.4ms	remaining: 139ms
# 51:	learn: 0.0976590	total: 28.9ms	remaining: 138ms
# 52:	learn: 0.0958589	total: 29.5ms	remaining: 137ms
# 53:	learn: 0.0930137	total: 29.9ms	remaining: 136ms
# 54:	learn: 0.0911587	total: 30.5ms	remaining: 136ms
# 55:	learn: 0.0894338	total: 31ms	remaining: 135ms
# 56:	learn: 0.0875848	total: 31.5ms	remaining: 134ms
# 57:	learn: 0.0849466	total: 32ms	remaining: 133ms
# 58:	learn: 0.0833353	total: 32.5ms	remaining: 133ms
# 59:	learn: 0.0815842	total: 32.9ms	remaining: 132ms
# 60:	learn: 0.0798432	total: 33.4ms	remaining: 131ms
# 61:	learn: 0.0778662	total: 34ms	remaining: 130ms
# 62:	learn: 0.0766990	total: 34.5ms	remaining: 130ms
# 63:	learn: 0.0753634	total: 35ms	remaining: 129ms
# 64:	learn: 0.0739038	total: 35.5ms	remaining: 128ms
# 65:	learn: 0.0730578	total: 36ms	remaining: 128ms
# 66:	learn: 0.0714054	total: 36.5ms	remaining: 127ms
# 67:	learn: 0.0696239	total: 37ms	remaining: 126ms
# 68:	learn: 0.0684808	total: 37.5ms	remaining: 126ms
# 69:	learn: 0.0674849	total: 38ms	remaining: 125ms
# 70:	learn: 0.0665785	total: 38.6ms	remaining: 124ms
# 71:	learn: 0.0653188	total: 39ms	remaining: 124ms
# 72:	learn: 0.0641047	total: 39.5ms	remaining: 123ms
# 73:	learn: 0.0627871	total: 40ms	remaining: 122ms
# 74:	learn: 0.0618297	total: 40.5ms	remaining: 121ms
# 75:	learn: 0.0608384	total: 41ms	remaining: 121ms
# 76:	learn: 0.0600724	total: 41.6ms	remaining: 120ms
# 77:	learn: 0.0593052	total: 42.1ms	remaining: 120ms
# 78:	learn: 0.0583110	total: 42.5ms	remaining: 119ms
# 79:	learn: 0.0571458	total: 43ms	remaining: 118ms
# 80:	learn: 0.0563457	total: 43.5ms	remaining: 118ms
# 81:	learn: 0.0555632	total: 44.4ms	remaining: 118ms
# 82:	learn: 0.0545978	total: 45.3ms	remaining: 118ms
# 83:	learn: 0.0535074	total: 46ms	remaining: 118ms
# 84:	learn: 0.0526681	total: 46.6ms	remaining: 118ms
# 85:	learn: 0.0518280	total: 47.2ms	remaining: 117ms
# 86:	learn: 0.0509299	total: 48.5ms	remaining: 119ms
# 87:	learn: 0.0500658	total: 49.2ms	remaining: 119ms
# 88:	learn: 0.0491550	total: 49.8ms	remaining: 118ms
# 89:	learn: 0.0481676	total: 50.3ms	remaining: 117ms
# 90:	learn: 0.0475602	total: 50.8ms	remaining: 117ms
# 91:	learn: 0.0467320	total: 51.4ms	remaining: 116ms
# 92:	learn: 0.0461701	total: 51.9ms	remaining: 116ms
# 93:	learn: 0.0455066	total: 52.4ms	remaining: 115ms
# 94:	learn: 0.0451130	total: 52.9ms	remaining: 114ms
# 95:	learn: 0.0444811	total: 53.4ms	remaining: 114ms
# 96:	learn: 0.0438717	total: 53.9ms	remaining: 113ms
# 97:	learn: 0.0432384	total: 54.5ms	remaining: 112ms
# 98:	learn: 0.0426303	total: 55ms	remaining: 112ms
# 99:	learn: 0.0418681	total: 55.5ms	remaining: 111ms
# 100:	learn: 0.0415299	total: 56.1ms	remaining: 110ms
# 101:	learn: 0.0408620	total: 56.6ms	remaining: 110ms
# 102:	learn: 0.0404642	total: 57.1ms	remaining: 109ms
# 103:	learn: 0.0399462	total: 57.6ms	remaining: 109ms
# 104:	learn: 0.0394461	total: 58.1ms	remaining: 108ms
# 105:	learn: 0.0390484	total: 58.6ms	remaining: 107ms
# 106:	learn: 0.0386577	total: 59.7ms	remaining: 108ms
# 107:	learn: 0.0382092	total: 60.4ms	remaining: 107ms
# 108:	learn: 0.0378627	total: 61ms	remaining: 107ms
# 109:	learn: 0.0374341	total: 61.6ms	remaining: 106ms
# 110:	learn: 0.0370539	total: 62.2ms	remaining: 106ms
# 111:	learn: 0.0366909	total: 62.8ms	remaining: 105ms
# 112:	learn: 0.0362714	total: 63.3ms	remaining: 105ms
# 113:	learn: 0.0359390	total: 63.8ms	remaining: 104ms
# 114:	learn: 0.0356373	total: 64.4ms	remaining: 104ms
# 115:	learn: 0.0352441	total: 64.9ms	remaining: 103ms
# 116:	learn: 0.0348432	total: 65.4ms	remaining: 102ms
# 117:	learn: 0.0344838	total: 65.9ms	remaining: 102ms
# 118:	learn: 0.0341736	total: 66.4ms	remaining: 101ms
# 119:	learn: 0.0337353	total: 66.9ms	remaining: 100ms
# 120:	learn: 0.0334226	total: 67.4ms	remaining: 99.7ms
# 121:	learn: 0.0330923	total: 67.9ms	remaining: 99ms
# 122:	learn: 0.0327545	total: 68.4ms	remaining: 98.4ms
# 123:	learn: 0.0324834	total: 68.9ms	remaining: 97.8ms
# 124:	learn: 0.0321847	total: 69.4ms	remaining: 97.1ms
# 125:	learn: 0.0318738	total: 69.8ms	remaining: 96.5ms
# 126:	learn: 0.0315485	total: 70.5ms	remaining: 96.1ms
# 127:	learn: 0.0311871	total: 71ms	remaining: 95.5ms
# 128:	learn: 0.0309471	total: 71.6ms	remaining: 94.9ms
# 129:	learn: 0.0306727	total: 72.1ms	remaining: 94.3ms
# 130:	learn: 0.0303545	total: 72.6ms	remaining: 93.6ms
# 131:	learn: 0.0301035	total: 73.1ms	remaining: 93ms
# 132:	learn: 0.0298959	total: 73.7ms	remaining: 92.5ms
# 133:	learn: 0.0295801	total: 74.2ms	remaining: 91.9ms
# 134:	learn: 0.0293106	total: 75ms	remaining: 91.6ms
# 135:	learn: 0.0290410	total: 75.5ms	remaining: 91ms
# 136:	learn: 0.0286417	total: 76ms	remaining: 90.4ms
# 137:	learn: 0.0284351	total: 76.8ms	remaining: 90.1ms
# 138:	learn: 0.0281990	total: 77.3ms	remaining: 89.5ms
# 139:	learn: 0.0279114	total: 77.8ms	remaining: 88.9ms
# 140:	learn: 0.0276673	total: 78.6ms	remaining: 88.6ms
# 141:	learn: 0.0274538	total: 79.1ms	remaining: 88ms
# 142:	learn: 0.0271094	total: 79.6ms	remaining: 87.4ms
# 143:	learn: 0.0268910	total: 80.1ms	remaining: 86.7ms
# 144:	learn: 0.0266416	total: 80.5ms	remaining: 86.1ms
# 145:	learn: 0.0264187	total: 81ms	remaining: 85.5ms
# 146:	learn: 0.0261943	total: 81.5ms	remaining: 84.9ms
# 147:	learn: 0.0260369	total: 82.1ms	remaining: 84.3ms
# 148:	learn: 0.0258342	total: 82.6ms	remaining: 83.7ms
# 149:	learn: 0.0255521	total: 83.1ms	remaining: 83.1ms
# 150:	learn: 0.0253422	total: 83.4ms	remaining: 82.3ms
# 151:	learn: 0.0251646	total: 83.7ms	remaining: 81.5ms
# 152:	learn: 0.0250004	total: 84.3ms	remaining: 80.9ms
# 153:	learn: 0.0247436	total: 84.7ms	remaining: 80.3ms
# 154:	learn: 0.0245070	total: 85.2ms	remaining: 79.7ms
# 155:	learn: 0.0242762	total: 85.7ms	remaining: 79.2ms
# 156:	learn: 0.0241243	total: 86.3ms	remaining: 78.6ms
# 157:	learn: 0.0239263	total: 86.7ms	remaining: 77.9ms
# 158:	learn: 0.0237583	total: 87.2ms	remaining: 77.3ms
# 159:	learn: 0.0235604	total: 87.7ms	remaining: 76.7ms
# 160:	learn: 0.0233630	total: 88.2ms	remaining: 76.2ms
# 161:	learn: 0.0232104	total: 88.7ms	remaining: 75.6ms
# 162:	learn: 0.0230287	total: 89.2ms	remaining: 75ms
# 163:	learn: 0.0228371	total: 89.7ms	remaining: 74.4ms
# 164:	learn: 0.0227138	total: 90.2ms	remaining: 73.8ms
# 165:	learn: 0.0225303	total: 90.6ms	remaining: 73.2ms
# 166:	learn: 0.0223866	total: 91.2ms	remaining: 72.6ms
# 167:	learn: 0.0221807	total: 91.7ms	remaining: 72ms
# 168:	learn: 0.0220420	total: 92.2ms	remaining: 71.5ms
# 169:	learn: 0.0218657	total: 92.7ms	remaining: 70.9ms
# 170:	learn: 0.0217435	total: 93.1ms	remaining: 70.3ms
# 171:	learn: 0.0216306	total: 93.7ms	remaining: 69.8ms
# 172:	learn: 0.0214763	total: 94.2ms	remaining: 69.2ms
# 173:	learn: 0.0213307	total: 94.7ms	remaining: 68.6ms
# 174:	learn: 0.0211238	total: 95.2ms	remaining: 68ms
# 175:	learn: 0.0210114	total: 95.8ms	remaining: 67.5ms
# 176:	learn: 0.0208455	total: 96.2ms	remaining: 66.9ms
# 177:	learn: 0.0206372	total: 96.7ms	remaining: 66.3ms
# 178:	learn: 0.0205383	total: 97.2ms	remaining: 65.7ms
# 179:	learn: 0.0203362	total: 97.7ms	remaining: 65.1ms
# 180:	learn: 0.0201321	total: 98.2ms	remaining: 64.6ms
# 181:	learn: 0.0199462	total: 98.7ms	remaining: 64ms
# 182:	learn: 0.0198296	total: 99.2ms	remaining: 63.4ms
# 183:	learn: 0.0197240	total: 99.8ms	remaining: 62.9ms
# 184:	learn: 0.0196242	total: 100ms	remaining: 62.3ms
# 185:	learn: 0.0195175	total: 101ms	remaining: 61.7ms
# 186:	learn: 0.0193990	total: 101ms	remaining: 61.2ms
# 187:	learn: 0.0192914	total: 102ms	remaining: 60.6ms
# 188:	learn: 0.0191770	total: 102ms	remaining: 60ms
# 189:	learn: 0.0190790	total: 103ms	remaining: 59.5ms
# 190:	learn: 0.0189585	total: 103ms	remaining: 58.9ms
# 191:	learn: 0.0188682	total: 104ms	remaining: 58.4ms
# 192:	learn: 0.0187022	total: 105ms	remaining: 58.1ms
# 193:	learn: 0.0186154	total: 106ms	remaining: 57.8ms
# 194:	learn: 0.0185100	total: 107ms	remaining: 57.4ms
# 195:	learn: 0.0183676	total: 107ms	remaining: 56.8ms
# 196:	learn: 0.0182323	total: 108ms	remaining: 56.3ms
# 197:	learn: 0.0180913	total: 108ms	remaining: 55.8ms
# 198:	learn: 0.0179740	total: 109ms	remaining: 55.2ms
# 199:	learn: 0.0179079	total: 109ms	remaining: 54.7ms
# 200:	learn: 0.0178229	total: 110ms	remaining: 54.1ms
# 201:	learn: 0.0177265	total: 110ms	remaining: 53.6ms
# 202:	learn: 0.0176218	total: 111ms	remaining: 53ms
# 203:	learn: 0.0175256	total: 112ms	remaining: 52.5ms
# 204:	learn: 0.0174502	total: 112ms	remaining: 51.9ms
# 205:	learn: 0.0173241	total: 113ms	remaining: 51.4ms
# 206:	learn: 0.0172475	total: 113ms	remaining: 50.8ms
# 207:	learn: 0.0171517	total: 114ms	remaining: 50.2ms
# 208:	learn: 0.0170524	total: 114ms	remaining: 49.7ms
# 209:	learn: 0.0169095	total: 115ms	remaining: 49.1ms
# 210:	learn: 0.0167947	total: 115ms	remaining: 48.5ms
# 211:	learn: 0.0167329	total: 116ms	remaining: 48ms
# 212:	learn: 0.0166352	total: 116ms	remaining: 47.5ms
# 213:	learn: 0.0165192	total: 117ms	remaining: 47ms
# 214:	learn: 0.0164010	total: 117ms	remaining: 46.4ms
# 215:	learn: 0.0163090	total: 118ms	remaining: 45.9ms
# 216:	learn: 0.0162145	total: 118ms	remaining: 45.3ms
# 217:	learn: 0.0161410	total: 119ms	remaining: 44.8ms
# 218:	learn: 0.0160729	total: 119ms	remaining: 44.2ms
# 219:	learn: 0.0159885	total: 120ms	remaining: 43.6ms
# 220:	learn: 0.0159220	total: 121ms	remaining: 43.1ms
# 221:	learn: 0.0158011	total: 121ms	remaining: 42.5ms
# 222:	learn: 0.0157295	total: 122ms	remaining: 42ms
# 223:	learn: 0.0156093	total: 122ms	remaining: 41.5ms
# 224:	learn: 0.0155169	total: 123ms	remaining: 41ms
# 225:	learn: 0.0154668	total: 124ms	remaining: 40.5ms
# 226:	learn: 0.0153820	total: 124ms	remaining: 40ms
# 227:	learn: 0.0152986	total: 125ms	remaining: 39.5ms
# 228:	learn: 0.0152350	total: 126ms	remaining: 39ms
# 229:	learn: 0.0151749	total: 126ms	remaining: 38.5ms
# 230:	learn: 0.0150773	total: 127ms	remaining: 37.9ms
# 231:	learn: 0.0150047	total: 127ms	remaining: 37.4ms
# 232:	learn: 0.0149422	total: 128ms	remaining: 36.8ms
# 233:	learn: 0.0148631	total: 129ms	remaining: 36.3ms
# 234:	learn: 0.0148062	total: 129ms	remaining: 35.7ms
# 235:	learn: 0.0147261	total: 130ms	remaining: 35.1ms
# 236:	learn: 0.0146504	total: 130ms	remaining: 34.6ms
# 237:	learn: 0.0145768	total: 131ms	remaining: 34ms
# 238:	learn: 0.0144951	total: 131ms	remaining: 33.5ms
# 239:	learn: 0.0144083	total: 132ms	remaining: 32.9ms
# 240:	learn: 0.0143044	total: 132ms	remaining: 32.4ms
# 241:	learn: 0.0142453	total: 133ms	remaining: 31.8ms
# 242:	learn: 0.0141438	total: 133ms	remaining: 31.3ms
# 243:	learn: 0.0140566	total: 134ms	remaining: 30.7ms
# 244:	learn: 0.0140084	total: 134ms	remaining: 30.1ms
# 245:	learn: 0.0139350	total: 135ms	remaining: 29.6ms
# 246:	learn: 0.0138787	total: 135ms	remaining: 29ms
# 247:	learn: 0.0137961	total: 136ms	remaining: 28.5ms
# 248:	learn: 0.0137044	total: 136ms	remaining: 27.9ms
# 249:	learn: 0.0136516	total: 137ms	remaining: 27.4ms
# 250:	learn: 0.0135585	total: 137ms	remaining: 26.8ms
# 251:	learn: 0.0134985	total: 138ms	remaining: 26.3ms
# 252:	learn: 0.0134444	total: 138ms	remaining: 25.7ms
# 253:	learn: 0.0133718	total: 139ms	remaining: 25.2ms
# 254:	learn: 0.0133174	total: 139ms	remaining: 24.6ms
# 255:	learn: 0.0132626	total: 140ms	remaining: 24.1ms
# 256:	learn: 0.0132174	total: 141ms	remaining: 23.6ms
# 257:	learn: 0.0131592	total: 142ms	remaining: 23.1ms
# 258:	learn: 0.0130888	total: 142ms	remaining: 22.5ms
# 259:	learn: 0.0130268	total: 143ms	remaining: 22ms
# 260:	learn: 0.0129410	total: 144ms	remaining: 21.5ms
# 261:	learn: 0.0129006	total: 144ms	remaining: 20.9ms
# 262:	learn: 0.0128421	total: 145ms	remaining: 20.4ms
# 263:	learn: 0.0127969	total: 145ms	remaining: 19.8ms
# 264:	learn: 0.0127412	total: 146ms	remaining: 19.2ms
# 265:	learn: 0.0126915	total: 146ms	remaining: 18.7ms
# 266:	learn: 0.0126321	total: 147ms	remaining: 18.2ms
# 267:	learn: 0.0125862	total: 147ms	remaining: 17.6ms
# 268:	learn: 0.0125406	total: 148ms	remaining: 17ms
# 269:	learn: 0.0124807	total: 149ms	remaining: 16.5ms
# 270:	learn: 0.0124257	total: 149ms	remaining: 16ms
# 271:	learn: 0.0123705	total: 150ms	remaining: 15.4ms
# 272:	learn: 0.0123077	total: 150ms	remaining: 14.9ms
# 273:	learn: 0.0122309	total: 151ms	remaining: 14.3ms
# 274:	learn: 0.0121676	total: 151ms	remaining: 13.8ms
# 275:	learn: 0.0121260	total: 152ms	remaining: 13.2ms
# 276:	learn: 0.0120649	total: 152ms	remaining: 12.6ms
# 277:	learn: 0.0120276	total: 153ms	remaining: 12.1ms
# 278:	learn: 0.0119720	total: 153ms	remaining: 11.5ms
# 279:	learn: 0.0119312	total: 154ms	remaining: 11ms
# 280:	learn: 0.0118801	total: 154ms	remaining: 10.4ms
# 281:	learn: 0.0118339	total: 155ms	remaining: 9.88ms
# 282:	learn: 0.0117879	total: 155ms	remaining: 9.33ms
# 283:	learn: 0.0117532	total: 156ms	remaining: 8.78ms
# 284:	learn: 0.0116829	total: 156ms	remaining: 8.23ms
# 285:	learn: 0.0116395	total: 157ms	remaining: 7.68ms
# 286:	learn: 0.0115950	total: 157ms	remaining: 7.13ms
# 287:	learn: 0.0115506	total: 159ms	remaining: 6.61ms
# 288:	learn: 0.0115096	total: 159ms	remaining: 6.05ms
# 289:	learn: 0.0114746	total: 159ms	remaining: 5.5ms
# 290:	learn: 0.0114226	total: 160ms	remaining: 4.95ms
# 291:	learn: 0.0113655	total: 160ms	remaining: 4.39ms
# 292:	learn: 0.0113149	total: 161ms	remaining: 3.84ms
# 293:	learn: 0.0112610	total: 161ms	remaining: 3.29ms
# 294:	learn: 0.0112209	total: 162ms	remaining: 2.74ms
# 295:	learn: 0.0111845	total: 166ms	remaining: 2.24ms
# 296:	learn: 0.0111366	total: 166ms	remaining: 1.68ms
# 297:	learn: 0.0110830	total: 167ms	remaining: 1.12ms
# 298:	learn: 0.0110194	total: 168ms	remaining: 560us
# 299:	learn: 0.0109590	total: 168ms	remaining: 0us
# Среднее значение accuracy при 10-кратной кросс-валидации: 0.96

# %% [markdown]
# Однократная оценка эффективности (accuracy): 0,973
#
# Среднее значение accuracy по 5-кратной кросс-валидации:0,966
#
# Среднее значение accuracy при 10-кратной кросс-валидации: 0,96
